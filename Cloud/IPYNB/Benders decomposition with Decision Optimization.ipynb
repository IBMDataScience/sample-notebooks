# %% [markdown]
# # Benders decomposition with Decision Optimization
#
# This tutorial includes everything you need to set up Decision Optimization engines, build a mathematical programming model, then use the benders decomposition on it.
#
# **Table of contents:**
#
# -  [Describe the business problem](#Describe-the-business-problem)
# *  [How Decision Optimization can help](#How-Decision-Optimization-can-help)
# *  [Use Decision Optimization](#Use-Decision-Optimization)
#     *  [Step 1: Set up the prescriptive model](#Step-1:-Set-up-the-prescriptive-model)
#     *  [Step 2: Solve the problem with default CPLEX algorithm](#Step-2:-Solve-the-problem-with-default-CPLEX-algorithm)
#     *  [Step 3: Apply a Benders strategy](#Step-3:-Apply-a-Benders-strategy)
#     *  [Step 4: Use the CPLEX annotations to guide CPLEX in your Benders decomposition](#Step-4:-Use-the-CPLEX-annotations-to-guide-CPLEX-in-your-Benders-decomposition)
# *  [Summary](#Summary)
# ****

# %% [markdown]
# ### Describe the business problem
#
# Benders decomposition is an approach to solve mathematical programming problems with a decomposable structure.
#
# Since V12.7, CPLEX can decompose the model into a single master and (possibly multiple) subproblems.
#
# To do so, CPLEX can use annotations that you supply for your model or can automatically do the decomposition.
# This approach can be applied to mixed-integer linear programs (MILP). For certain types of problems, this approach can offer significant performance improvements.
#
# **Note**:
# If your problem does not match such decomposition, CPLEX will raise an error at solve time.
#
# CPLEX will produce an error CPXERR_BAD_DECOMPOSITION if the annotated decomposition does not yield disjoint subproblems

# %% [markdown]
# #### Learn more about Benders decomposition

# %% [markdown]
# The popular acceptance of the original paper suggesting a decomposition or partitioning of a model to support solution of mixed integer programs gave rise to "Benders algorithm" as the name.
#
# * *J. Benders*. <i>Partitioning procedures for solving mixed-variables programming problems in Numerische Mathematik, volume 4, issue 1, pages 238–252, 1962</i>
#
# Other researchers developed the theory of cut-generating linear programs (CGLP) to further this practice.
# * *M. Fischetti, D. Salvagnin, A. Zanette*. <i>A note on the selection of Benders’ cuts in Mathematical Programming, series B, volume 124, pages 175-182, 2010</i>
#
# Others applied the practice to practical operations research. This technical report describes Benders algorithm in "modern" terms and offers implementation hints.
# * *M. Fischetti, I. Ljubic, M. Sinnl*. <i>Benders decomposition without separability: a computational study for capacitated facility location problems in Technical Report University of Padova, 2016</i>

# %% [markdown]
# ## How Decision Optimization can help
#
# * Prescriptive analytics (Decision Optimization) technology recommends actions that are based on desired outcomes.  It takes into account specific scenarios, resources, and knowledge of past and current events. With this insight, your organization can make better decisions and have greater control of business outcomes.
#
# * Prescriptive analytics is the next step on the path to insight-based actions. It creates value through synergy with predictive analytics, which analyzes data to predict future outcomes.
#
# * Prescriptive analytics takes that insight to the next level by suggesting the optimal way to handle that future situation. Organizations that can act fast in dynamic conditions and make superior decisions in uncertain environments gain a strong competitive advantage.
# <br/>
#
# <u>With prescriptive analytics, you can:</u>
#
# * Automate the complex decisions and trade-offs to better manage your limited resources.
# * Take advantage of a future opportunity or mitigate a future risk.
# * Proactively update recommendations based on changing events.
# * Meet operational goals, increase customer loyalty, prevent threats and fraud, and optimize business processes.

# %% [markdown]
# ## Use Decision Optimization

# %% [markdown]
# ### Step 1: Set up the prescriptive model

# %% [markdown]
# Write a toy model to show how to use the annotation api.
#
# This model is not important: it just matches a Benders decomposition, that is CPLEX can apply its new algorithm without any error.
#
# The aim of this notebook is to discover and learn how to successfully apply Benders decomposition, not to see huge performance differences between a standard solve and a Benders-based solve.

# %%
d1 = 25
d2 = 35

Costs = [[20,  15,  22,  27,  13,  4,  15,  6,  15,  22,  25,  13,  7,  28,  14,  5,  8,  1,  17,  3,  19,  17,  22,  12,  14],
   [2,  15,  16,  16,  10,  13,  4,  2,  6,  29,  10,  8,  20,  11,  8,  11,  28,  17,  10,  29,  3,  24,  12,  11,  11],
   [13,  14,  6,  17,  14,  13,  8,  29,  19,  26,  22,  0,  8,  29,  15,  20,  5,  20,  26,  17, 24, 10, 24, 9, 1],
   [7, 27, 24, 3, 4, 23, 11, 9, 18, 1, 29, 24, 16, 9, 8, 3, 18, 24, 10, 12, 1, 3, 15, 29, 3],
   [25, 26, 29, 6, 24, 8, 2, 10, 17, 0, 4, 7, 2, 17, 2, 27, 24, 20, 18, 5, 5, 2, 21, 26, 20],
   [29, 5, 15, 5, 4, 26, 18, 8, 2, 14, 13, 6, 14, 28, 16, 28, 23, 8, 5, 8, 10, 28, 17, 0, 23],
   [12, 16, 10, 16, 17, 10, 29, 11, 28, 22, 25, 8, 27, 12, 10, 28, 7, 5, 3, 9, 18, 10, 15, 16, 2],
   [12, 9, 14, 23, 26, 4, 3, 3, 22, 12, 11, 9, 19, 5, 6, 16, 1, 1, 9, 20, 23, 23, 27, 4, 11],
   [18, 13, 28, 29, 3, 28, 16, 11, 9, 2, 7, 20, 13, 23, 6, 10, 3, 16, 14, 2, 15, 17, 1, 19, 27],
   [29, 17, 17, 14, 21, 18, 8, 21, 9, 20, 14, 6, 29, 24, 24, 4, 18, 16, 21, 24, 26, 0, 26, 9, 5],
   [27, 24, 21, 28, 17, 18, 10, 10, 26, 25, 13, 18, 2, 9, 16, 26, 10, 22, 5, 17, 15, 0, 9, 0, 16],
   [13, 15, 17, 21, 25, 9, 22, 13, 20, 15, 1, 17, 18, 10, 2, 27, 19, 21, 14, 26, 29, 13, 28, 28, 15],
   [16, 12, 2, 2, 9, 27, 11, 14, 12, 2, 14, 29, 3, 12, 18, 6, 7, 9, 1, 5, 19, 14, 11, 29, 4],
   [1, 15, 27, 29, 16, 17, 10, 10, 17, 19, 6, 10, 20, 20, 19, 10, 19, 26, 15, 7, 20, 19, 13, 3, 22],
   [22, 14, 12, 3, 22, 6, 15, 3, 6, 10, 9, 13, 11, 21, 6, 19, 29, 4, 5, 21, 7, 12, 13, 11, 22],
   [9, 27, 22, 29, 11, 14, 1, 19, 21, 2, 4, 13, 17, 9, 10, 17, 13, 8, 24, 13, 26, 27, 23, 4, 21],
   [3, 14, 26, 18, 17, 3, 1, 11, 13, 8, 22, 3, 18, 26, 17, 15, 22, 10, 19, 23, 13, 14, 17, 18, 27],
   [21, 14, 1, 28, 28, 0, 0, 29, 12, 23, 22, 17, 19, 2, 10, 19, 4, 18, 28, 13, 27, 12, 9, 29, 22],
   [29, 3, 20, 5, 5, 23, 28, 16, 1, 8, 26, 23, 11, 11, 21, 17, 13, 21, 3, 8, 6, 15, 18, 6, 24],
   [14, 20, 26, 10, 17, 20, 5, 9, 25, 20, 14, 22, 5, 12, 0, 18, 7, 0, 8, 15, 21, 12, 26, 7, 21],
   [7, 7, 1, 9, 24, 29, 0, 3, 29, 24, 1, 6, 14, 0, 11, 5, 21, 12, 15, 1, 25, 4, 7, 17, 16],
   [8, 18, 15, 6, 1, 22, 26, 13, 19, 20, 12, 15, 19, 27, 13, 3, 22, 22, 22, 20, 0, 4, 24, 13, 25],
   [14, 6, 29, 23, 8, 5, 4, 18, 21, 29, 18, 2, 2, 3, 7, 13, 12, 9, 2, 18, 26, 3, 18, 7, 7],
   [5, 8, 4, 8, 25, 4, 6, 20, 14, 21, 18, 16, 15, 11, 7, 8, 20, 27, 22, 7, 5, 8, 24, 11, 8],
   [0, 8, 29, 25, 29, 0, 12, 25, 19, 9, 19, 25, 27, 21, 2, 23, 2, 25, 17, 6, 0, 6, 15, 2, 15],
   [23, 24, 10, 26, 7, 5, 5, 26, 1, 16, 22, 8, 24, 9, 16, 17, 1, 26, 20, 23, 18, 20, 23, 2, 19],
   [16, 3, 9, 21, 15, 29, 8, 26, 20, 12, 18, 27, 29, 15, 24, 9, 17, 24, 3, 5, 21, 28, 7, 1, 12],
   [1, 11, 21, 1, 13, 14, 16, 14, 17, 25, 18, 9, 19, 26, 1, 13, 15, 6, 14, 10, 12, 19, 0, 15, 7],
   [20, 14, 7, 5, 8, 16, 12, 0, 5, 14, 18, 16, 24, 27, 20, 7, 11, 3, 16, 8, 2, 2, 4, 0, 3],
   [26, 19, 27, 29, 8, 9, 8, 10, 18, 4, 6, 0, 5, 17, 12, 18, 17, 17, 13, 0, 16, 12, 18, 19, 16],
   [3, 12, 11, 28, 3, 2, 14, 14, 17, 29, 18, 14, 19, 24, 9, 27, 4, 19, 6, 24, 19, 3, 28, 20, 4],
   [2, 0, 21, 14, 21, 12, 27, 6, 20, 29, 13, 21, 23, 0, 20, 4, 11, 27, 3, 11, 21, 11, 21, 4, 17],
   [20, 26, 5, 8, 18, 14, 12, 12, 24, 3, 8, 0, 25, 16, 19, 21, 7, 4, 23, 21, 20, 28, 6, 21, 19],
   [16, 18, 9, 1, 9, 7, 14, 6, 28, 26, 3, 14, 27, 4, 9, 9, 1, 9, 24, 3, 14, 13, 18, 3, 27],
   [1, 19, 7, 20, 26, 27, 0, 7, 4, 0, 13, 8, 10, 17, 14, 19, 21, 21, 14, 15, 22, 14, 5, 27, 0]];

# %%
R1 = range(1,d1)
R2 = range(1,d2);

dim  = range(1,d1*d2+1)

# %% [markdown]
# Create one model instance, with a name. Set the log output to true so that you can see when CPLEX enables the Benders algorithm.

# %%
# first import the Model class from docplex.mp
from docplex.mp.model import Model

m = Model(name='benders', log_output=True)

# %%
X = m.continuous_var_dict([(i,j) for i in R2 for j in R1])
Y = m.integer_var_dict(R1, 0, 1)


bendersPartition = {(i,j) : i for i in R2 for j in R1}

# %%
m.minimize( m.sum( Costs[i][j]*X[i,j] for i in R2 for j in R1) + sum(Y[i] for i in R1) )


m.add_constraints( m.sum( X[i,j] for j in R1) ==1 for i in R2)
    
m.add_constraints( X[i,j] - Y[j] <= 0 for i in R2 for j in R1)
# Out:
# [docplex.mp.LinearConstraint[](x1-x817,LE,0),
#  docplex.mp.LinearConstraint[](x2-x818,LE,0),
#  docplex.mp.LinearConstraint[](x3-x819,LE,0),
#  docplex.mp.LinearConstraint[](x4-x820,LE,0),
#  docplex.mp.LinearConstraint[](x5-x821,LE,0),
#  docplex.mp.LinearConstraint[](x6-x822,LE,0),
#  docplex.mp.LinearConstraint[](x7-x823,LE,0),
#  docplex.mp.LinearConstraint[](x8-x824,LE,0),
#  docplex.mp.LinearConstraint[](x9-x825,LE,0),
#  docplex.mp.LinearConstraint[](x10-x826,LE,0),
#  docplex.mp.LinearConstraint[](x11-x827,LE,0),
#  docplex.mp.LinearConstraint[](x12-x828,LE,0),
#  docplex.mp.LinearConstraint[](x13-x829,LE,0),
#  docplex.mp.LinearConstraint[](x14-x830,LE,0),
#  docplex.mp.LinearConstraint[](x15-x831,LE,0),
#  docplex.mp.LinearConstraint[](x16-x832,LE,0),
#  docplex.mp.LinearConstraint[](x17-x833,LE,0),
#  docplex.mp.LinearConstraint[](x18-x834,LE,0),
#  docplex.mp.LinearConstraint[](x19-x835,LE,0),
#  docplex.mp.LinearConstraint[](x20-x836,LE,0),
#  docplex.mp.LinearConstraint[](x21-x837,LE,0),
#  docplex.mp.LinearConstraint[](x22-x838,LE,0),
#  docplex.mp.LinearConstraint[](x23-x839,LE,0),
#  docplex.mp.LinearConstraint[](x24-x840,LE,0),
#  docplex.mp.LinearConstraint[](x25-x817,LE,0),
#  docplex.mp.LinearConstraint[](x26-x818,LE,0),
#  docplex.mp.LinearConstraint[](x27-x819,LE,0),
#  docplex.mp.LinearConstraint[](x28-x820,LE,0),
#  docplex.mp.LinearConstraint[](x29-x821,LE,0),
#  docplex.mp.LinearConstraint[](x30-x822,LE,0),
#  docplex.mp.LinearConstraint[](x31-x823,LE,0),
#  docplex.mp.LinearConstraint[](x32-x824,LE,0),
#  docplex.mp.LinearConstraint[](x33-x825,LE,0),
#  docplex.mp.LinearConstraint[](x34-x826,LE,0),
#  docplex.mp.LinearConstraint[](x35-x827,LE,0),
#  docplex.mp.LinearConstraint[](x36-x828,LE,0),
#  docplex.mp.LinearConstraint[](x37-x829,LE,0),
#  docplex.mp.LinearConstraint[](x38-x830,LE,0),
#  docplex.mp.LinearConstraint[](x39-x831,LE,0),
#  docplex.mp.LinearConstraint[](x40-x832,LE,0),
#  docplex.mp.LinearConstraint[](x41-x833,LE,0),
#  docplex.mp.LinearConstraint[](x42-x834,LE,0),
#  docplex.mp.LinearConstraint[](x43-x835,LE,0),
#  docplex.mp.LinearConstraint[](x44-x836,LE,0),
#  docplex.mp.LinearConstraint[](x45-x837,LE,0),
#  docplex.mp.LinearConstraint[](x46-x838,LE,0),
#  docplex.mp.LinearConstraint[](x47-x839,LE,0),
#  docplex.mp.LinearConstraint[](x48-x840,LE,0),
#  docplex.mp.LinearConstraint[](x49-x817,LE,0),
#  docplex.mp.LinearConstraint[](x50-x818,LE,0),
#  docplex.mp.LinearConstraint[](x51-x819,LE,0),
#  docplex.mp.LinearConstraint[](x52-x820,LE,0),
#  docplex.mp.LinearConstraint[](x53-x821,LE,0),
#  docplex.mp.LinearConstraint[](x54-x822,LE,0),
#  docplex.mp.LinearConstraint[](x55-x823,LE,0),
#  docplex.mp.LinearConstraint[](x56-x824,LE,0),
#  docplex.mp.LinearConstraint[](x57-x825,LE,0),
#  docplex.mp.LinearConstraint[](x58-x826,LE,0),
#  docplex.mp.LinearConstraint[](x59-x827,LE,0),
#  docplex.mp.LinearConstraint[](x60-x828,LE,0),
#  docplex.mp.LinearConstraint[](x61-x829,LE,0),
#  docplex.mp.LinearConstraint[](x62-x830,LE,0),
#  docplex.mp.LinearConstraint[](x63-x831,LE,0),
#  docplex.mp.LinearConstraint[](x64-x832,LE,0),
#  docplex.mp.LinearConstraint[](x65-x833,LE,0),
#  docplex.mp.LinearConstraint[](x66-x834,LE,0),
#  docplex.mp.LinearConstraint[](x67-x835,LE,0),
#  docplex.mp.LinearConstraint[](x68-x836,LE,0),
#  docplex.mp.LinearConstraint[](x69-x837,LE,0),
#  docplex.mp.LinearConstraint[](x70-x838,LE,0),
#  docplex.mp.LinearConstraint[](x71-x839,LE,0),
#  docplex.mp.LinearConstraint[](x72-x840,LE,0),
#  docplex.mp.LinearConstraint[](x73-x817,LE,0),
#  docplex.mp.LinearConstraint[](x74-x818,LE,0),
#  docplex.mp.LinearConstraint[](x75-x819,LE,0),
#  docplex.mp.LinearConstraint[](x76-x820,LE,0),
#  docplex.mp.LinearConstraint[](x77-x821,LE,0),
#  docplex.mp.LinearConstraint[](x78-x822,LE,0),
#  docplex.mp.LinearConstraint[](x79-x823,LE,0),
#  docplex.mp.LinearConstraint[](x80-x824,LE,0),
#  docplex.mp.LinearConstraint[](x81-x825,LE,0),
#  docplex.mp.LinearConstraint[](x82-x826,LE,0),
#  docplex.mp.LinearConstraint[](x83-x827,LE,0),
#  docplex.mp.LinearConstraint[](x84-x828,LE,0),
#  docplex.mp.LinearConstraint[](x85-x829,LE,0),
#  docplex.mp.LinearConstraint[](x86-x830,LE,0),
#  docplex.mp.LinearConstraint[](x87-x831,LE,0),
#  docplex.mp.LinearConstraint[](x88-x832,LE,0),
#  docplex.mp.LinearConstraint[](x89-x833,LE,0),
#  docplex.mp.LinearConstraint[](x90-x834,LE,0),
#  docplex.mp.LinearConstraint[](x91-x835,LE,0),
#  docplex.mp.LinearConstraint[](x92-x836,LE,0),
#  docplex.mp.LinearConstraint[](x93-x837,LE,0),
#  docplex.mp.LinearConstraint[](x94-x838,LE,0),
#  docplex.mp.LinearConstraint[](x95-x839,LE,0),
#  docplex.mp.LinearConstraint[](x96-x840,LE,0),
#  docplex.mp.LinearConstraint[](x97-x817,LE,0),
#  docplex.mp.LinearConstraint[](x98-x818,LE,0),
#  docplex.mp.LinearConstraint[](x99-x819,LE,0),
#  docplex.mp.LinearConstraint[](x100-x820,LE,0),
#  docplex.mp.LinearConstraint[](x101-x821,LE,0),
#  docplex.mp.LinearConstraint[](x102-x822,LE,0),
#  docplex.mp.LinearConstraint[](x103-x823,LE,0),
#  docplex.mp.LinearConstraint[](x104-x824,LE,0),
#  docplex.mp.LinearConstraint[](x105-x825,LE,0),
#  docplex.mp.LinearConstraint[](x106-x826,LE,0),
#  docplex.mp.LinearConstraint[](x107-x827,LE,0),
#  docplex.mp.LinearConstraint[](x108-x828,LE,0),
#  docplex.mp.LinearConstraint[](x109-x829,LE,0),
#  docplex.mp.LinearConstraint[](x110-x830,LE,0),
#  docplex.mp.LinearConstraint[](x111-x831,LE,0),
#  docplex.mp.LinearConstraint[](x112-x832,LE,0),
#  docplex.mp.LinearConstraint[](x113-x833,LE,0),
#  docplex.mp.LinearConstraint[](x114-x834,LE,0),
#  docplex.mp.LinearConstraint[](x115-x835,LE,0),
#  docplex.mp.LinearConstraint[](x116-x836,LE,0),
#  docplex.mp.LinearConstraint[](x117-x837,LE,0),
#  docplex.mp.LinearConstraint[](x118-x838,LE,0),
#  docplex.mp.LinearConstraint[](x119-x839,LE,0),
#  docplex.mp.LinearConstraint[](x120-x840,LE,0),
#  docplex.mp.LinearConstraint[](x121-x817,LE,0),
#  docplex.mp.LinearConstraint[](x122-x818,LE,0),
#  docplex.mp.LinearConstraint[](x123-x819,LE,0),
#  docplex.mp.LinearConstraint[](x124-x820,LE,0),
#  docplex.mp.LinearConstraint[](x125-x821,LE,0),
#  docplex.mp.LinearConstraint[](x126-x822,LE,0),
#  docplex.mp.LinearConstraint[](x127-x823,LE,0),
#  docplex.mp.LinearConstraint[](x128-x824,LE,0),
#  docplex.mp.LinearConstraint[](x129-x825,LE,0),
#  docplex.mp.LinearConstraint[](x130-x826,LE,0),
#  docplex.mp.LinearConstraint[](x131-x827,LE,0),
#  docplex.mp.LinearConstraint[](x132-x828,LE,0),
#  docplex.mp.LinearConstraint[](x133-x829,LE,0),
#  docplex.mp.LinearConstraint[](x134-x830,LE,0),
#  docplex.mp.LinearConstraint[](x135-x831,LE,0),
#  docplex.mp.LinearConstraint[](x136-x832,LE,0),
#  docplex.mp.LinearConstraint[](x137-x833,LE,0),
#  docplex.mp.LinearConstraint[](x138-x834,LE,0),
#  docplex.mp.LinearConstraint[](x139-x835,LE,0),
#  docplex.mp.LinearConstraint[](x140-x836,LE,0),
#  docplex.mp.LinearConstraint[](x141-x837,LE,0),
#  docplex.mp.LinearConstraint[](x142-x838,LE,0),
#  docplex.mp.LinearConstraint[](x143-x839,LE,0),
#  docplex.mp.LinearConstraint[](x144-x840,LE,0),
#  docplex.mp.LinearConstraint[](x145-x817,LE,0),
#  docplex.mp.LinearConstraint[](x146-x818,LE,0),
#  docplex.mp.LinearConstraint[](x147-x819,LE,0),
#  docplex.mp.LinearConstraint[](x148-x820,LE,0),
#  docplex.mp.LinearConstraint[](x149-x821,LE,0),
#  docplex.mp.LinearConstraint[](x150-x822,LE,0),
#  docplex.mp.LinearConstraint[](x151-x823,LE,0),
#  docplex.mp.LinearConstraint[](x152-x824,LE,0),
#  docplex.mp.LinearConstraint[](x153-x825,LE,0),
#  docplex.mp.LinearConstraint[](x154-x826,LE,0),
#  docplex.mp.LinearConstraint[](x155-x827,LE,0),
#  docplex.mp.LinearConstraint[](x156-x828,LE,0),
#  docplex.mp.LinearConstraint[](x157-x829,LE,0),
#  docplex.mp.LinearConstraint[](x158-x830,LE,0),
#  docplex.mp.LinearConstraint[](x159-x831,LE,0),
#  docplex.mp.LinearConstraint[](x160-x832,LE,0),
#  docplex.mp.LinearConstraint[](x161-x833,LE,0),
#  docplex.mp.LinearConstraint[](x162-x834,LE,0),
#  docplex.mp.LinearConstraint[](x163-x835,LE,0),
#  docplex.mp.LinearConstraint[](x164-x836,LE,0),
#  docplex.mp.LinearConstraint[](x165-x837,LE,0),
#  docplex.mp.LinearConstraint[](x166-x838,LE,0),
#  docplex.mp.LinearConstraint[](x167-x839,LE,0),
#  docplex.mp.LinearConstraint[](x168-x840,LE,0),
#  docplex.mp.LinearConstraint[](x169-x817,LE,0),
#  docplex.mp.LinearConstraint[](x170-x818,LE,0),
#  docplex.mp.LinearConstraint[](x171-x819,LE,0),
#  docplex.mp.LinearConstraint[](x172-x820,LE,0),
#  docplex.mp.LinearConstraint[](x173-x821,LE,0),
#  docplex.mp.LinearConstraint[](x174-x822,LE,0),
#  docplex.mp.LinearConstraint[](x175-x823,LE,0),
#  docplex.mp.LinearConstraint[](x176-x824,LE,0),
#  docplex.mp.LinearConstraint[](x177-x825,LE,0),
#  docplex.mp.LinearConstraint[](x178-x826,LE,0),
#  docplex.mp.LinearConstraint[](x179-x827,LE,0),
#  docplex.mp.LinearConstraint[](x180-x828,LE,0),
#  docplex.mp.LinearConstraint[](x181-x829,LE,0),
#  docplex.mp.LinearConstraint[](x182-x830,LE,0),
#  docplex.mp.LinearConstraint[](x183-x831,LE,0),
#  docplex.mp.LinearConstraint[](x184-x832,LE,0),
#  docplex.mp.LinearConstraint[](x185-x833,LE,0),
#  docplex.mp.LinearConstraint[](x186-x834,LE,0),
#  docplex.mp.LinearConstraint[](x187-x835,LE,0),
#  docplex.mp.LinearConstraint[](x188-x836,LE,0),
#  docplex.mp.LinearConstraint[](x189-x837,LE,0),
#  docplex.mp.LinearConstraint[](x190-x838,LE,0),
#  docplex.mp.LinearConstraint[](x191-x839,LE,0),
#  docplex.mp.LinearConstraint[](x192-x840,LE,0),
#  docplex.mp.LinearConstraint[](x193-x817,LE,0),
#  docplex.mp.LinearConstraint[](x194-x818,LE,0),
#  docplex.mp.LinearConstraint[](x195-x819,LE,0),
#  docplex.mp.LinearConstraint[](x196-x820,LE,0),
#  docplex.mp.LinearConstraint[](x197-x821,LE,0),
#  docplex.mp.LinearConstraint[](x198-x822,LE,0),
#  docplex.mp.LinearConstraint[](x199-x823,LE,0),
#  docplex.mp.LinearConstraint[](x200-x824,LE,0),
#  docplex.mp.LinearConstraint[](x201-x825,LE,0),
#  docplex.mp.LinearConstraint[](x202-x826,LE,0),
#  docplex.mp.LinearConstraint[](x203-x827,LE,0),
#  docplex.mp.LinearConstraint[](x204-x828,LE,0),
#  docplex.mp.LinearConstraint[](x205-x829,LE,0),
#  docplex.mp.LinearConstraint[](x206-x830,LE,0),
#  docplex.mp.LinearConstraint[](x207-x831,LE,0),
#  docplex.mp.LinearConstraint[](x208-x832,LE,0),
#  docplex.mp.LinearConstraint[](x209-x833,LE,0),
#  docplex.mp.LinearConstraint[](x210-x834,LE,0),
#  docplex.mp.LinearConstraint[](x211-x835,LE,0),
#  docplex.mp.LinearConstraint[](x212-x836,LE,0),
#  docplex.mp.LinearConstraint[](x213-x837,LE,0),
#  docplex.mp.LinearConstraint[](x214-x838,LE,0),
#  docplex.mp.LinearConstraint[](x215-x839,LE,0),
#  docplex.mp.LinearConstraint[](x216-x840,LE,0),
#  docplex.mp.LinearConstraint[](x217-x817,LE,0),
#  docplex.mp.LinearConstraint[](x218-x818,LE,0),
#  docplex.mp.LinearConstraint[](x219-x819,LE,0),
#  docplex.mp.LinearConstraint[](x220-x820,LE,0),
#  docplex.mp.LinearConstraint[](x221-x821,LE,0),
#  docplex.mp.LinearConstraint[](x222-x822,LE,0),
#  docplex.mp.LinearConstraint[](x223-x823,LE,0),
#  docplex.mp.LinearConstraint[](x224-x824,LE,0),
#  docplex.mp.LinearConstraint[](x225-x825,LE,0),
#  docplex.mp.LinearConstraint[](x226-x826,LE,0),
#  docplex.mp.LinearConstraint[](x227-x827,LE,0),
#  docplex.mp.LinearConstraint[](x228-x828,LE,0),
#  docplex.mp.LinearConstraint[](x229-x829,LE,0),
#  docplex.mp.LinearConstraint[](x230-x830,LE,0),
#  docplex.mp.LinearConstraint[](x231-x831,LE,0),
#  docplex.mp.LinearConstraint[](x232-x832,LE,0),
#  docplex.mp.LinearConstraint[](x233-x833,LE,0),
#  docplex.mp.LinearConstraint[](x234-x834,LE,0),
#  docplex.mp.LinearConstraint[](x235-x835,LE,0),
#  docplex.mp.LinearConstraint[](x236-x836,LE,0),
#  docplex.mp.LinearConstraint[](x237-x837,LE,0),
#  docplex.mp.LinearConstraint[](x238-x838,LE,0),
#  docplex.mp.LinearConstraint[](x239-x839,LE,0),
#  docplex.mp.LinearConstraint[](x240-x840,LE,0),
#  docplex.mp.LinearConstraint[](x241-x817,LE,0),
#  docplex.mp.LinearConstraint[](x242-x818,LE,0),
#  docplex.mp.LinearConstraint[](x243-x819,LE,0),
#  docplex.mp.LinearConstraint[](x244-x820,LE,0),
#  docplex.mp.LinearConstraint[](x245-x821,LE,0),
#  docplex.mp.LinearConstraint[](x246-x822,LE,0),
#  docplex.mp.LinearConstraint[](x247-x823,LE,0),
#  docplex.mp.LinearConstraint[](x248-x824,LE,0),
#  docplex.mp.LinearConstraint[](x249-x825,LE,0),
#  docplex.mp.LinearConstraint[](x250-x826,LE,0),
#  docplex.mp.LinearConstraint[](x251-x827,LE,0),
#  docplex.mp.LinearConstraint[](x252-x828,LE,0),
#  docplex.mp.LinearConstraint[](x253-x829,LE,0),
#  docplex.mp.LinearConstraint[](x254-x830,LE,0),
#  docplex.mp.LinearConstraint[](x255-x831,LE,0),
#  docplex.mp.LinearConstraint[](x256-x832,LE,0),
#  docplex.mp.LinearConstraint[](x257-x833,LE,0),
#  docplex.mp.LinearConstraint[](x258-x834,LE,0),
#  docplex.mp.LinearConstraint[](x259-x835,LE,0),
#  docplex.mp.LinearConstraint[](x260-x836,LE,0),
#  docplex.mp.LinearConstraint[](x261-x837,LE,0),
#  docplex.mp.LinearConstraint[](x262-x838,LE,0),
#  docplex.mp.LinearConstraint[](x263-x839,LE,0),
#  docplex.mp.LinearConstraint[](x264-x840,LE,0),
#  docplex.mp.LinearConstraint[](x265-x817,LE,0),
#  docplex.mp.LinearConstraint[](x266-x818,LE,0),
#  docplex.mp.LinearConstraint[](x267-x819,LE,0),
#  docplex.mp.LinearConstraint[](x268-x820,LE,0),
#  docplex.mp.LinearConstraint[](x269-x821,LE,0),
#  docplex.mp.LinearConstraint[](x270-x822,LE,0),
#  docplex.mp.LinearConstraint[](x271-x823,LE,0),
#  docplex.mp.LinearConstraint[](x272-x824,LE,0),
#  docplex.mp.LinearConstraint[](x273-x825,LE,0),
#  docplex.mp.LinearConstraint[](x274-x826,LE,0),
#  docplex.mp.LinearConstraint[](x275-x827,LE,0),
#  docplex.mp.LinearConstraint[](x276-x828,LE,0),
#  docplex.mp.LinearConstraint[](x277-x829,LE,0),
#  docplex.mp.LinearConstraint[](x278-x830,LE,0),
#  docplex.mp.LinearConstraint[](x279-x831,LE,0),
#  docplex.mp.LinearConstraint[](x280-x832,LE,0),
#  docplex.mp.LinearConstraint[](x281-x833,LE,0),
#  docplex.mp.LinearConstraint[](x282-x834,LE,0),
#  docplex.mp.LinearConstraint[](x283-x835,LE,0),
#  docplex.mp.LinearConstraint[](x284-x836,LE,0),
#  docplex.mp.LinearConstraint[](x285-x837,LE,0),
#  docplex.mp.LinearConstraint[](x286-x838,LE,0),
#  docplex.mp.LinearConstraint[](x287-x839,LE,0),
#  docplex.mp.LinearConstraint[](x288-x840,LE,0),
#  docplex.mp.LinearConstraint[](x289-x817,LE,0),
#  docplex.mp.LinearConstraint[](x290-x818,LE,0),
#  docplex.mp.LinearConstraint[](x291-x819,LE,0),
#  docplex.mp.LinearConstraint[](x292-x820,LE,0),
#  docplex.mp.LinearConstraint[](x293-x821,LE,0),
#  docplex.mp.LinearConstraint[](x294-x822,LE,0),
#  docplex.mp.LinearConstraint[](x295-x823,LE,0),
#  docplex.mp.LinearConstraint[](x296-x824,LE,0),
#  docplex.mp.LinearConstraint[](x297-x825,LE,0),
#  docplex.mp.LinearConstraint[](x298-x826,LE,0),
#  docplex.mp.LinearConstraint[](x299-x827,LE,0),
#  docplex.mp.LinearConstraint[](x300-x828,LE,0),
#  docplex.mp.LinearConstraint[](x301-x829,LE,0),
#  docplex.mp.LinearConstraint[](x302-x830,LE,0),
#  docplex.mp.LinearConstraint[](x303-x831,LE,0),
#  docplex.mp.LinearConstraint[](x304-x832,LE,0),
#  docplex.mp.LinearConstraint[](x305-x833,LE,0),
#  docplex.mp.LinearConstraint[](x306-x834,LE,0),
#  docplex.mp.LinearConstraint[](x307-x835,LE,0),
#  docplex.mp.LinearConstraint[](x308-x836,LE,0),
#  docplex.mp.LinearConstraint[](x309-x837,LE,0),
#  docplex.mp.LinearConstraint[](x310-x838,LE,0),
#  docplex.mp.LinearConstraint[](x311-x839,LE,0),
#  docplex.mp.LinearConstraint[](x312-x840,LE,0),
#  docplex.mp.LinearConstraint[](x313-x817,LE,0),
#  docplex.mp.LinearConstraint[](x314-x818,LE,0),
#  docplex.mp.LinearConstraint[](x315-x819,LE,0),
#  docplex.mp.LinearConstraint[](x316-x820,LE,0),
#  docplex.mp.LinearConstraint[](x317-x821,LE,0),
#  docplex.mp.LinearConstraint[](x318-x822,LE,0),
#  docplex.mp.LinearConstraint[](x319-x823,LE,0),
#  docplex.mp.LinearConstraint[](x320-x824,LE,0),
#  docplex.mp.LinearConstraint[](x321-x825,LE,0),
#  docplex.mp.LinearConstraint[](x322-x826,LE,0),
#  docplex.mp.LinearConstraint[](x323-x827,LE,0),
#  docplex.mp.LinearConstraint[](x324-x828,LE,0),
#  docplex.mp.LinearConstraint[](x325-x829,LE,0),
#  docplex.mp.LinearConstraint[](x326-x830,LE,0),
#  docplex.mp.LinearConstraint[](x327-x831,LE,0),
#  docplex.mp.LinearConstraint[](x328-x832,LE,0),
#  docplex.mp.LinearConstraint[](x329-x833,LE,0),
#  docplex.mp.LinearConstraint[](x330-x834,LE,0),
#  docplex.mp.LinearConstraint[](x331-x835,LE,0),
#  docplex.mp.LinearConstraint[](x332-x836,LE,0),
#  docplex.mp.LinearConstraint[](x333-x837,LE,0),
#  docplex.mp.LinearConstraint[](x334-x838,LE,0),
#  docplex.mp.LinearConstraint[](x335-x839,LE,0),
#  docplex.mp.LinearConstraint[](x336-x840,LE,0),
#  docplex.mp.LinearConstraint[](x337-x817,LE,0),
#  docplex.mp.LinearConstraint[](x338-x818,LE,0),
#  docplex.mp.LinearConstraint[](x339-x819,LE,0),
#  docplex.mp.LinearConstraint[](x340-x820,LE,0),
#  docplex.mp.LinearConstraint[](x341-x821,LE,0),
#  docplex.mp.LinearConstraint[](x342-x822,LE,0),
#  docplex.mp.LinearConstraint[](x343-x823,LE,0),
#  docplex.mp.LinearConstraint[](x344-x824,LE,0),
#  docplex.mp.LinearConstraint[](x345-x825,LE,0),
#  docplex.mp.LinearConstraint[](x346-x826,LE,0),
#  docplex.mp.LinearConstraint[](x347-x827,LE,0),
#  docplex.mp.LinearConstraint[](x348-x828,LE,0),
#  docplex.mp.LinearConstraint[](x349-x829,LE,0),
#  docplex.mp.LinearConstraint[](x350-x830,LE,0),
#  docplex.mp.LinearConstraint[](x351-x831,LE,0),
#  docplex.mp.LinearConstraint[](x352-x832,LE,0),
#  docplex.mp.LinearConstraint[](x353-x833,LE,0),
#  docplex.mp.LinearConstraint[](x354-x834,LE,0),
#  docplex.mp.LinearConstraint[](x355-x835,LE,0),
#  docplex.mp.LinearConstraint[](x356-x836,LE,0),
#  docplex.mp.LinearConstraint[](x357-x837,LE,0),
#  docplex.mp.LinearConstraint[](x358-x838,LE,0),
#  docplex.mp.LinearConstraint[](x359-x839,LE,0),
#  docplex.mp.LinearConstraint[](x360-x840,LE,0),
#  docplex.mp.LinearConstraint[](x361-x817,LE,0),
#  docplex.mp.LinearConstraint[](x362-x818,LE,0),
#  docplex.mp.LinearConstraint[](x363-x819,LE,0),
#  docplex.mp.LinearConstraint[](x364-x820,LE,0),
#  docplex.mp.LinearConstraint[](x365-x821,LE,0),
#  docplex.mp.LinearConstraint[](x366-x822,LE,0),
#  docplex.mp.LinearConstraint[](x367-x823,LE,0),
#  docplex.mp.LinearConstraint[](x368-x824,LE,0),
#  docplex.mp.LinearConstraint[](x369-x825,LE,0),
#  docplex.mp.LinearConstraint[](x370-x826,LE,0),
#  docplex.mp.LinearConstraint[](x371-x827,LE,0),
#  docplex.mp.LinearConstraint[](x372-x828,LE,0),
#  docplex.mp.LinearConstraint[](x373-x829,LE,0),
#  docplex.mp.LinearConstraint[](x374-x830,LE,0),
#  docplex.mp.LinearConstraint[](x375-x831,LE,0),
#  docplex.mp.LinearConstraint[](x376-x832,LE,0),
#  docplex.mp.LinearConstraint[](x377-x833,LE,0),
#  docplex.mp.LinearConstraint[](x378-x834,LE,0),
#  docplex.mp.LinearConstraint[](x379-x835,LE,0),
#  docplex.mp.LinearConstraint[](x380-x836,LE,0),
#  docplex.mp.LinearConstraint[](x381-x837,LE,0),
#  docplex.mp.LinearConstraint[](x382-x838,LE,0),
#  docplex.mp.LinearConstraint[](x383-x839,LE,0),
#  docplex.mp.LinearConstraint[](x384-x840,LE,0),
#  docplex.mp.LinearConstraint[](x385-x817,LE,0),
#  docplex.mp.LinearConstraint[](x386-x818,LE,0),
#  docplex.mp.LinearConstraint[](x387-x819,LE,0),
#  docplex.mp.LinearConstraint[](x388-x820,LE,0),
#  docplex.mp.LinearConstraint[](x389-x821,LE,0),
#  docplex.mp.LinearConstraint[](x390-x822,LE,0),
#  docplex.mp.LinearConstraint[](x391-x823,LE,0),
#  docplex.mp.LinearConstraint[](x392-x824,LE,0),
#  docplex.mp.LinearConstraint[](x393-x825,LE,0),
#  docplex.mp.LinearConstraint[](x394-x826,LE,0),
#  docplex.mp.LinearConstraint[](x395-x827,LE,0),
#  docplex.mp.LinearConstraint[](x396-x828,LE,0),
#  docplex.mp.LinearConstraint[](x397-x829,LE,0),
#  docplex.mp.LinearConstraint[](x398-x830,LE,0),
#  docplex.mp.LinearConstraint[](x399-x831,LE,0),
#  docplex.mp.LinearConstraint[](x400-x832,LE,0),
#  docplex.mp.LinearConstraint[](x401-x833,LE,0),
#  docplex.mp.LinearConstraint[](x402-x834,LE,0),
#  docplex.mp.LinearConstraint[](x403-x835,LE,0),
#  docplex.mp.LinearConstraint[](x404-x836,LE,0),
#  docplex.mp.LinearConstraint[](x405-x837,LE,0),
#  docplex.mp.LinearConstraint[](x406-x838,LE,0),
#  docplex.mp.LinearConstraint[](x407-x839,LE,0),
#  docplex.mp.LinearConstraint[](x408-x840,LE,0),
#  docplex.mp.LinearConstraint[](x409-x817,LE,0),
#  docplex.mp.LinearConstraint[](x410-x818,LE,0),
#  docplex.mp.LinearConstraint[](x411-x819,LE,0),
#  docplex.mp.LinearConstraint[](x412-x820,LE,0),
#  docplex.mp.LinearConstraint[](x413-x821,LE,0),
#  docplex.mp.LinearConstraint[](x414-x822,LE,0),
#  docplex.mp.LinearConstraint[](x415-x823,LE,0),
#  docplex.mp.LinearConstraint[](x416-x824,LE,0),
#  docplex.mp.LinearConstraint[](x417-x825,LE,0),
#  docplex.mp.LinearConstraint[](x418-x826,LE,0),
#  docplex.mp.LinearConstraint[](x419-x827,LE,0),
#  docplex.mp.LinearConstraint[](x420-x828,LE,0),
#  docplex.mp.LinearConstraint[](x421-x829,LE,0),
#  docplex.mp.LinearConstraint[](x422-x830,LE,0),
#  docplex.mp.LinearConstraint[](x423-x831,LE,0),
#  docplex.mp.LinearConstraint[](x424-x832,LE,0),
#  docplex.mp.LinearConstraint[](x425-x833,LE,0),
#  docplex.mp.LinearConstraint[](x426-x834,LE,0),
#  docplex.mp.LinearConstraint[](x427-x835,LE,0),
#  docplex.mp.LinearConstraint[](x428-x836,LE,0),
#  docplex.mp.LinearConstraint[](x429-x837,LE,0),
#  docplex.mp.LinearConstraint[](x430-x838,LE,0),
#  docplex.mp.LinearConstraint[](x431-x839,LE,0),
#  docplex.mp.LinearConstraint[](x432-x840,LE,0),
#  docplex.mp.LinearConstraint[](x433-x817,LE,0),
#  docplex.mp.LinearConstraint[](x434-x818,LE,0),
#  docplex.mp.LinearConstraint[](x435-x819,LE,0),
#  docplex.mp.LinearConstraint[](x436-x820,LE,0),
#  docplex.mp.LinearConstraint[](x437-x821,LE,0),
#  docplex.mp.LinearConstraint[](x438-x822,LE,0),
#  docplex.mp.LinearConstraint[](x439-x823,LE,0),
#  docplex.mp.LinearConstraint[](x440-x824,LE,0),
#  docplex.mp.LinearConstraint[](x441-x825,LE,0),
#  docplex.mp.LinearConstraint[](x442-x826,LE,0),
#  docplex.mp.LinearConstraint[](x443-x827,LE,0),
#  docplex.mp.LinearConstraint[](x444-x828,LE,0),
#  docplex.mp.LinearConstraint[](x445-x829,LE,0),
#  docplex.mp.LinearConstraint[](x446-x830,LE,0),
#  docplex.mp.LinearConstraint[](x447-x831,LE,0),
#  docplex.mp.LinearConstraint[](x448-x832,LE,0),
#  docplex.mp.LinearConstraint[](x449-x833,LE,0),
#  docplex.mp.LinearConstraint[](x450-x834,LE,0),
#  docplex.mp.LinearConstraint[](x451-x835,LE,0),
#  docplex.mp.LinearConstraint[](x452-x836,LE,0),
#  docplex.mp.LinearConstraint[](x453-x837,LE,0),
#  docplex.mp.LinearConstraint[](x454-x838,LE,0),
#  docplex.mp.LinearConstraint[](x455-x839,LE,0),
#  docplex.mp.LinearConstraint[](x456-x840,LE,0),
#  docplex.mp.LinearConstraint[](x457-x817,LE,0),
#  docplex.mp.LinearConstraint[](x458-x818,LE,0),
#  docplex.mp.LinearConstraint[](x459-x819,LE,0),
#  docplex.mp.LinearConstraint[](x460-x820,LE,0),
#  docplex.mp.LinearConstraint[](x461-x821,LE,0),
#  docplex.mp.LinearConstraint[](x462-x822,LE,0),
#  docplex.mp.LinearConstraint[](x463-x823,LE,0),
#  docplex.mp.LinearConstraint[](x464-x824,LE,0),
#  docplex.mp.LinearConstraint[](x465-x825,LE,0),
#  docplex.mp.LinearConstraint[](x466-x826,LE,0),
#  docplex.mp.LinearConstraint[](x467-x827,LE,0),
#  docplex.mp.LinearConstraint[](x468-x828,LE,0),
#  docplex.mp.LinearConstraint[](x469-x829,LE,0),
#  docplex.mp.LinearConstraint[](x470-x830,LE,0),
#  docplex.mp.LinearConstraint[](x471-x831,LE,0),
#  docplex.mp.LinearConstraint[](x472-x832,LE,0),
#  docplex.mp.LinearConstraint[](x473-x833,LE,0),
#  docplex.mp.LinearConstraint[](x474-x834,LE,0),
#  docplex.mp.LinearConstraint[](x475-x835,LE,0),
#  docplex.mp.LinearConstraint[](x476-x836,LE,0),
#  docplex.mp.LinearConstraint[](x477-x837,LE,0),
#  docplex.mp.LinearConstraint[](x478-x838,LE,0),
#  docplex.mp.LinearConstraint[](x479-x839,LE,0),
#  docplex.mp.LinearConstraint[](x480-x840,LE,0),
#  docplex.mp.LinearConstraint[](x481-x817,LE,0),
#  docplex.mp.LinearConstraint[](x482-x818,LE,0),
#  docplex.mp.LinearConstraint[](x483-x819,LE,0),
#  docplex.mp.LinearConstraint[](x484-x820,LE,0),
#  docplex.mp.LinearConstraint[](x485-x821,LE,0),
#  docplex.mp.LinearConstraint[](x486-x822,LE,0),
#  docplex.mp.LinearConstraint[](x487-x823,LE,0),
#  docplex.mp.LinearConstraint[](x488-x824,LE,0),
#  docplex.mp.LinearConstraint[](x489-x825,LE,0),
#  docplex.mp.LinearConstraint[](x490-x826,LE,0),
#  docplex.mp.LinearConstraint[](x491-x827,LE,0),
#  docplex.mp.LinearConstraint[](x492-x828,LE,0),
#  docplex.mp.LinearConstraint[](x493-x829,LE,0),
#  docplex.mp.LinearConstraint[](x494-x830,LE,0),
#  docplex.mp.LinearConstraint[](x495-x831,LE,0),
#  docplex.mp.LinearConstraint[](x496-x832,LE,0),
#  docplex.mp.LinearConstraint[](x497-x833,LE,0),
#  docplex.mp.LinearConstraint[](x498-x834,LE,0),
#  docplex.mp.LinearConstraint[](x499-x835,LE,0),
#  docplex.mp.LinearConstraint[](x500-x836,LE,0),
#  docplex.mp.LinearConstraint[](x501-x837,LE,0),
#  docplex.mp.LinearConstraint[](x502-x838,LE,0),
#  docplex.mp.LinearConstraint[](x503-x839,LE,0),
#  docplex.mp.LinearConstraint[](x504-x840,LE,0),
#  docplex.mp.LinearConstraint[](x505-x817,LE,0),
#  docplex.mp.LinearConstraint[](x506-x818,LE,0),
#  docplex.mp.LinearConstraint[](x507-x819,LE,0),
#  docplex.mp.LinearConstraint[](x508-x820,LE,0),
#  docplex.mp.LinearConstraint[](x509-x821,LE,0),
#  docplex.mp.LinearConstraint[](x510-x822,LE,0),
#  docplex.mp.LinearConstraint[](x511-x823,LE,0),
#  docplex.mp.LinearConstraint[](x512-x824,LE,0),
#  docplex.mp.LinearConstraint[](x513-x825,LE,0),
#  docplex.mp.LinearConstraint[](x514-x826,LE,0),
#  docplex.mp.LinearConstraint[](x515-x827,LE,0),
#  docplex.mp.LinearConstraint[](x516-x828,LE,0),
#  docplex.mp.LinearConstraint[](x517-x829,LE,0),
#  docplex.mp.LinearConstraint[](x518-x830,LE,0),
#  docplex.mp.LinearConstraint[](x519-x831,LE,0),
#  docplex.mp.LinearConstraint[](x520-x832,LE,0),
#  docplex.mp.LinearConstraint[](x521-x833,LE,0),
#  docplex.mp.LinearConstraint[](x522-x834,LE,0),
#  docplex.mp.LinearConstraint[](x523-x835,LE,0),
#  docplex.mp.LinearConstraint[](x524-x836,LE,0),
#  docplex.mp.LinearConstraint[](x525-x837,LE,0),
#  docplex.mp.LinearConstraint[](x526-x838,LE,0),
#  docplex.mp.LinearConstraint[](x527-x839,LE,0),
#  docplex.mp.LinearConstraint[](x528-x840,LE,0),
#  docplex.mp.LinearConstraint[](x529-x817,LE,0),
#  docplex.mp.LinearConstraint[](x530-x818,LE,0),
#  docplex.mp.LinearConstraint[](x531-x819,LE,0),
#  docplex.mp.LinearConstraint[](x532-x820,LE,0),
#  docplex.mp.LinearConstraint[](x533-x821,LE,0),
#  docplex.mp.LinearConstraint[](x534-x822,LE,0),
#  docplex.mp.LinearConstraint[](x535-x823,LE,0),
#  docplex.mp.LinearConstraint[](x536-x824,LE,0),
#  docplex.mp.LinearConstraint[](x537-x825,LE,0),
#  docplex.mp.LinearConstraint[](x538-x826,LE,0),
#  docplex.mp.LinearConstraint[](x539-x827,LE,0),
#  docplex.mp.LinearConstraint[](x540-x828,LE,0),
#  docplex.mp.LinearConstraint[](x541-x829,LE,0),
#  docplex.mp.LinearConstraint[](x542-x830,LE,0),
#  docplex.mp.LinearConstraint[](x543-x831,LE,0),
#  docplex.mp.LinearConstraint[](x544-x832,LE,0),
#  docplex.mp.LinearConstraint[](x545-x833,LE,0),
#  docplex.mp.LinearConstraint[](x546-x834,LE,0),
#  docplex.mp.LinearConstraint[](x547-x835,LE,0),
#  docplex.mp.LinearConstraint[](x548-x836,LE,0),
#  docplex.mp.LinearConstraint[](x549-x837,LE,0),
#  docplex.mp.LinearConstraint[](x550-x838,LE,0),
#  docplex.mp.LinearConstraint[](x551-x839,LE,0),
#  docplex.mp.LinearConstraint[](x552-x840,LE,0),
#  docplex.mp.LinearConstraint[](x553-x817,LE,0),
#  docplex.mp.LinearConstraint[](x554-x818,LE,0),
#  docplex.mp.LinearConstraint[](x555-x819,LE,0),
#  docplex.mp.LinearConstraint[](x556-x820,LE,0),
#  docplex.mp.LinearConstraint[](x557-x821,LE,0),
#  docplex.mp.LinearConstraint[](x558-x822,LE,0),
#  docplex.mp.LinearConstraint[](x559-x823,LE,0),
#  docplex.mp.LinearConstraint[](x560-x824,LE,0),
#  docplex.mp.LinearConstraint[](x561-x825,LE,0),
#  docplex.mp.LinearConstraint[](x562-x826,LE,0),
#  docplex.mp.LinearConstraint[](x563-x827,LE,0),
#  docplex.mp.LinearConstraint[](x564-x828,LE,0),
#  docplex.mp.LinearConstraint[](x565-x829,LE,0),
#  docplex.mp.LinearConstraint[](x566-x830,LE,0),
#  docplex.mp.LinearConstraint[](x567-x831,LE,0),
#  docplex.mp.LinearConstraint[](x568-x832,LE,0),
#  docplex.mp.LinearConstraint[](x569-x833,LE,0),
#  docplex.mp.LinearConstraint[](x570-x834,LE,0),
#  docplex.mp.LinearConstraint[](x571-x835,LE,0),
#  docplex.mp.LinearConstraint[](x572-x836,LE,0),
#  docplex.mp.LinearConstraint[](x573-x837,LE,0),
#  docplex.mp.LinearConstraint[](x574-x838,LE,0),
#  docplex.mp.LinearConstraint[](x575-x839,LE,0),
#  docplex.mp.LinearConstraint[](x576-x840,LE,0),
#  docplex.mp.LinearConstraint[](x577-x817,LE,0),
#  docplex.mp.LinearConstraint[](x578-x818,LE,0),
#  docplex.mp.LinearConstraint[](x579-x819,LE,0),
#  docplex.mp.LinearConstraint[](x580-x820,LE,0),
#  docplex.mp.LinearConstraint[](x581-x821,LE,0),
#  docplex.mp.LinearConstraint[](x582-x822,LE,0),
#  docplex.mp.LinearConstraint[](x583-x823,LE,0),
#  docplex.mp.LinearConstraint[](x584-x824,LE,0),
#  docplex.mp.LinearConstraint[](x585-x825,LE,0),
#  docplex.mp.LinearConstraint[](x586-x826,LE,0),
#  docplex.mp.LinearConstraint[](x587-x827,LE,0),
#  docplex.mp.LinearConstraint[](x588-x828,LE,0),
#  docplex.mp.LinearConstraint[](x589-x829,LE,0),
#  docplex.mp.LinearConstraint[](x590-x830,LE,0),
#  docplex.mp.LinearConstraint[](x591-x831,LE,0),
#  docplex.mp.LinearConstraint[](x592-x832,LE,0),
#  docplex.mp.LinearConstraint[](x593-x833,LE,0),
#  docplex.mp.LinearConstraint[](x594-x834,LE,0),
#  docplex.mp.LinearConstraint[](x595-x835,LE,0),
#  docplex.mp.LinearConstraint[](x596-x836,LE,0),
#  docplex.mp.LinearConstraint[](x597-x837,LE,0),
#  docplex.mp.LinearConstraint[](x598-x838,LE,0),
#  docplex.mp.LinearConstraint[](x599-x839,LE,0),
#  docplex.mp.LinearConstraint[](x600-x840,LE,0),
#  docplex.mp.LinearConstraint[](x601-x817,LE,0),
#  docplex.mp.LinearConstraint[](x602-x818,LE,0),
#  docplex.mp.LinearConstraint[](x603-x819,LE,0),
#  docplex.mp.LinearConstraint[](x604-x820,LE,0),
#  docplex.mp.LinearConstraint[](x605-x821,LE,0),
#  docplex.mp.LinearConstraint[](x606-x822,LE,0),
#  docplex.mp.LinearConstraint[](x607-x823,LE,0),
#  docplex.mp.LinearConstraint[](x608-x824,LE,0),
#  docplex.mp.LinearConstraint[](x609-x825,LE,0),
#  docplex.mp.LinearConstraint[](x610-x826,LE,0),
#  docplex.mp.LinearConstraint[](x611-x827,LE,0),
#  docplex.mp.LinearConstraint[](x612-x828,LE,0),
#  docplex.mp.LinearConstraint[](x613-x829,LE,0),
#  docplex.mp.LinearConstraint[](x614-x830,LE,0),
#  docplex.mp.LinearConstraint[](x615-x831,LE,0),
#  docplex.mp.LinearConstraint[](x616-x832,LE,0),
#  docplex.mp.LinearConstraint[](x617-x833,LE,0),
#  docplex.mp.LinearConstraint[](x618-x834,LE,0),
#  docplex.mp.LinearConstraint[](x619-x835,LE,0),
#  docplex.mp.LinearConstraint[](x620-x836,LE,0),
#  docplex.mp.LinearConstraint[](x621-x837,LE,0),
#  docplex.mp.LinearConstraint[](x622-x838,LE,0),
#  docplex.mp.LinearConstraint[](x623-x839,LE,0),
#  docplex.mp.LinearConstraint[](x624-x840,LE,0),
#  docplex.mp.LinearConstraint[](x625-x817,LE,0),
#  docplex.mp.LinearConstraint[](x626-x818,LE,0),
#  docplex.mp.LinearConstraint[](x627-x819,LE,0),
#  docplex.mp.LinearConstraint[](x628-x820,LE,0),
#  docplex.mp.LinearConstraint[](x629-x821,LE,0),
#  docplex.mp.LinearConstraint[](x630-x822,LE,0),
#  docplex.mp.LinearConstraint[](x631-x823,LE,0),
#  docplex.mp.LinearConstraint[](x632-x824,LE,0),
#  docplex.mp.LinearConstraint[](x633-x825,LE,0),
#  docplex.mp.LinearConstraint[](x634-x826,LE,0),
#  docplex.mp.LinearConstraint[](x635-x827,LE,0),
#  docplex.mp.LinearConstraint[](x636-x828,LE,0),
#  docplex.mp.LinearConstraint[](x637-x829,LE,0),
#  docplex.mp.LinearConstraint[](x638-x830,LE,0),
#  docplex.mp.LinearConstraint[](x639-x831,LE,0),
#  docplex.mp.LinearConstraint[](x640-x832,LE,0),
#  docplex.mp.LinearConstraint[](x641-x833,LE,0),
#  docplex.mp.LinearConstraint[](x642-x834,LE,0),
#  docplex.mp.LinearConstraint[](x643-x835,LE,0),
#  docplex.mp.LinearConstraint[](x644-x836,LE,0),
#  docplex.mp.LinearConstraint[](x645-x837,LE,0),
#  docplex.mp.LinearConstraint[](x646-x838,LE,0),
#  docplex.mp.LinearConstraint[](x647-x839,LE,0),
#  docplex.mp.LinearConstraint[](x648-x840,LE,0),
#  docplex.mp.LinearConstraint[](x649-x817,LE,0),
#  docplex.mp.LinearConstraint[](x650-x818,LE,0),
#  docplex.mp.LinearConstraint[](x651-x819,LE,0),
#  docplex.mp.LinearConstraint[](x652-x820,LE,0),
#  docplex.mp.LinearConstraint[](x653-x821,LE,0),
#  docplex.mp.LinearConstraint[](x654-x822,LE,0),
#  docplex.mp.LinearConstraint[](x655-x823,LE,0),
#  docplex.mp.LinearConstraint[](x656-x824,LE,0),
#  docplex.mp.LinearConstraint[](x657-x825,LE,0),
#  docplex.mp.LinearConstraint[](x658-x826,LE,0),
#  docplex.mp.LinearConstraint[](x659-x827,LE,0),
#  docplex.mp.LinearConstraint[](x660-x828,LE,0),
#  docplex.mp.LinearConstraint[](x661-x829,LE,0),
#  docplex.mp.LinearConstraint[](x662-x830,LE,0),
#  docplex.mp.LinearConstraint[](x663-x831,LE,0),
#  docplex.mp.LinearConstraint[](x664-x832,LE,0),
#  docplex.mp.LinearConstraint[](x665-x833,LE,0),
#  docplex.mp.LinearConstraint[](x666-x834,LE,0),
#  docplex.mp.LinearConstraint[](x667-x835,LE,0),
#  docplex.mp.LinearConstraint[](x668-x836,LE,0),
#  docplex.mp.LinearConstraint[](x669-x837,LE,0),
#  docplex.mp.LinearConstraint[](x670-x838,LE,0),
#  docplex.mp.LinearConstraint[](x671-x839,LE,0),
#  docplex.mp.LinearConstraint[](x672-x840,LE,0),
#  docplex.mp.LinearConstraint[](x673-x817,LE,0),
#  docplex.mp.LinearConstraint[](x674-x818,LE,0),
#  docplex.mp.LinearConstraint[](x675-x819,LE,0),
#  docplex.mp.LinearConstraint[](x676-x820,LE,0),
#  docplex.mp.LinearConstraint[](x677-x821,LE,0),
#  docplex.mp.LinearConstraint[](x678-x822,LE,0),
#  docplex.mp.LinearConstraint[](x679-x823,LE,0),
#  docplex.mp.LinearConstraint[](x680-x824,LE,0),
#  docplex.mp.LinearConstraint[](x681-x825,LE,0),
#  docplex.mp.LinearConstraint[](x682-x826,LE,0),
#  docplex.mp.LinearConstraint[](x683-x827,LE,0),
#  docplex.mp.LinearConstraint[](x684-x828,LE,0),
#  docplex.mp.LinearConstraint[](x685-x829,LE,0),
#  docplex.mp.LinearConstraint[](x686-x830,LE,0),
#  docplex.mp.LinearConstraint[](x687-x831,LE,0),
#  docplex.mp.LinearConstraint[](x688-x832,LE,0),
#  docplex.mp.LinearConstraint[](x689-x833,LE,0),
#  docplex.mp.LinearConstraint[](x690-x834,LE,0),
#  docplex.mp.LinearConstraint[](x691-x835,LE,0),
#  docplex.mp.LinearConstraint[](x692-x836,LE,0),
#  docplex.mp.LinearConstraint[](x693-x837,LE,0),
#  docplex.mp.LinearConstraint[](x694-x838,LE,0),
#  docplex.mp.LinearConstraint[](x695-x839,LE,0),
#  docplex.mp.LinearConstraint[](x696-x840,LE,0),
#  docplex.mp.LinearConstraint[](x697-x817,LE,0),
#  docplex.mp.LinearConstraint[](x698-x818,LE,0),
#  docplex.mp.LinearConstraint[](x699-x819,LE,0),
#  docplex.mp.LinearConstraint[](x700-x820,LE,0),
#  docplex.mp.LinearConstraint[](x701-x821,LE,0),
#  docplex.mp.LinearConstraint[](x702-x822,LE,0),
#  docplex.mp.LinearConstraint[](x703-x823,LE,0),
#  docplex.mp.LinearConstraint[](x704-x824,LE,0),
#  docplex.mp.LinearConstraint[](x705-x825,LE,0),
#  docplex.mp.LinearConstraint[](x706-x826,LE,0),
#  docplex.mp.LinearConstraint[](x707-x827,LE,0),
#  docplex.mp.LinearConstraint[](x708-x828,LE,0),
#  docplex.mp.LinearConstraint[](x709-x829,LE,0),
#  docplex.mp.LinearConstraint[](x710-x830,LE,0),
#  docplex.mp.LinearConstraint[](x711-x831,LE,0),
#  docplex.mp.LinearConstraint[](x712-x832,LE,0),
#  docplex.mp.LinearConstraint[](x713-x833,LE,0),
#  docplex.mp.LinearConstraint[](x714-x834,LE,0),
#  docplex.mp.LinearConstraint[](x715-x835,LE,0),
#  docplex.mp.LinearConstraint[](x716-x836,LE,0),
#  docplex.mp.LinearConstraint[](x717-x837,LE,0),
#  docplex.mp.LinearConstraint[](x718-x838,LE,0),
#  docplex.mp.LinearConstraint[](x719-x839,LE,0),
#  docplex.mp.LinearConstraint[](x720-x840,LE,0),
#  docplex.mp.LinearConstraint[](x721-x817,LE,0),
#  docplex.mp.LinearConstraint[](x722-x818,LE,0),
#  docplex.mp.LinearConstraint[](x723-x819,LE,0),
#  docplex.mp.LinearConstraint[](x724-x820,LE,0),
#  docplex.mp.LinearConstraint[](x725-x821,LE,0),
#  docplex.mp.LinearConstraint[](x726-x822,LE,0),
#  docplex.mp.LinearConstraint[](x727-x823,LE,0),
#  docplex.mp.LinearConstraint[](x728-x824,LE,0),
#  docplex.mp.LinearConstraint[](x729-x825,LE,0),
#  docplex.mp.LinearConstraint[](x730-x826,LE,0),
#  docplex.mp.LinearConstraint[](x731-x827,LE,0),
#  docplex.mp.LinearConstraint[](x732-x828,LE,0),
#  docplex.mp.LinearConstraint[](x733-x829,LE,0),
#  docplex.mp.LinearConstraint[](x734-x830,LE,0),
#  docplex.mp.LinearConstraint[](x735-x831,LE,0),
#  docplex.mp.LinearConstraint[](x736-x832,LE,0),
#  docplex.mp.LinearConstraint[](x737-x833,LE,0),
#  docplex.mp.LinearConstraint[](x738-x834,LE,0),
#  docplex.mp.LinearConstraint[](x739-x835,LE,0),
#  docplex.mp.LinearConstraint[](x740-x836,LE,0),
#  docplex.mp.LinearConstraint[](x741-x837,LE,0),
#  docplex.mp.LinearConstraint[](x742-x838,LE,0),
#  docplex.mp.LinearConstraint[](x743-x839,LE,0),
#  docplex.mp.LinearConstraint[](x744-x840,LE,0),
#  docplex.mp.LinearConstraint[](x745-x817,LE,0),
#  docplex.mp.LinearConstraint[](x746-x818,LE,0),
#  docplex.mp.LinearConstraint[](x747-x819,LE,0),
#  docplex.mp.LinearConstraint[](x748-x820,LE,0),
#  docplex.mp.LinearConstraint[](x749-x821,LE,0),
#  docplex.mp.LinearConstraint[](x750-x822,LE,0),
#  docplex.mp.LinearConstraint[](x751-x823,LE,0),
#  docplex.mp.LinearConstraint[](x752-x824,LE,0),
#  docplex.mp.LinearConstraint[](x753-x825,LE,0),
#  docplex.mp.LinearConstraint[](x754-x826,LE,0),
#  docplex.mp.LinearConstraint[](x755-x827,LE,0),
#  docplex.mp.LinearConstraint[](x756-x828,LE,0),
#  docplex.mp.LinearConstraint[](x757-x829,LE,0),
#  docplex.mp.LinearConstraint[](x758-x830,LE,0),
#  docplex.mp.LinearConstraint[](x759-x831,LE,0),
#  docplex.mp.LinearConstraint[](x760-x832,LE,0),
#  docplex.mp.LinearConstraint[](x761-x833,LE,0),
#  docplex.mp.LinearConstraint[](x762-x834,LE,0),
#  docplex.mp.LinearConstraint[](x763-x835,LE,0),
#  docplex.mp.LinearConstraint[](x764-x836,LE,0),
#  docplex.mp.LinearConstraint[](x765-x837,LE,0),
#  docplex.mp.LinearConstraint[](x766-x838,LE,0),
#  docplex.mp.LinearConstraint[](x767-x839,LE,0),
#  docplex.mp.LinearConstraint[](x768-x840,LE,0),
#  docplex.mp.LinearConstraint[](x769-x817,LE,0),
#  docplex.mp.LinearConstraint[](x770-x818,LE,0),
#  docplex.mp.LinearConstraint[](x771-x819,LE,0),
#  docplex.mp.LinearConstraint[](x772-x820,LE,0),
#  docplex.mp.LinearConstraint[](x773-x821,LE,0),
#  docplex.mp.LinearConstraint[](x774-x822,LE,0),
#  docplex.mp.LinearConstraint[](x775-x823,LE,0),
#  docplex.mp.LinearConstraint[](x776-x824,LE,0),
#  docplex.mp.LinearConstraint[](x777-x825,LE,0),
#  docplex.mp.LinearConstraint[](x778-x826,LE,0),
#  docplex.mp.LinearConstraint[](x779-x827,LE,0),
#  docplex.mp.LinearConstraint[](x780-x828,LE,0),
#  docplex.mp.LinearConstraint[](x781-x829,LE,0),
#  docplex.mp.LinearConstraint[](x782-x830,LE,0),
#  docplex.mp.LinearConstraint[](x783-x831,LE,0),
#  docplex.mp.LinearConstraint[](x784-x832,LE,0),
#  docplex.mp.LinearConstraint[](x785-x833,LE,0),
#  docplex.mp.LinearConstraint[](x786-x834,LE,0),
#  docplex.mp.LinearConstraint[](x787-x835,LE,0),
#  docplex.mp.LinearConstraint[](x788-x836,LE,0),
#  docplex.mp.LinearConstraint[](x789-x837,LE,0),
#  docplex.mp.LinearConstraint[](x790-x838,LE,0),
#  docplex.mp.LinearConstraint[](x791-x839,LE,0),
#  docplex.mp.LinearConstraint[](x792-x840,LE,0),
#  docplex.mp.LinearConstraint[](x793-x817,LE,0),
#  docplex.mp.LinearConstraint[](x794-x818,LE,0),
#  docplex.mp.LinearConstraint[](x795-x819,LE,0),
#  docplex.mp.LinearConstraint[](x796-x820,LE,0),
#  docplex.mp.LinearConstraint[](x797-x821,LE,0),
#  docplex.mp.LinearConstraint[](x798-x822,LE,0),
#  docplex.mp.LinearConstraint[](x799-x823,LE,0),
#  docplex.mp.LinearConstraint[](x800-x824,LE,0),
#  docplex.mp.LinearConstraint[](x801-x825,LE,0),
#  docplex.mp.LinearConstraint[](x802-x826,LE,0),
#  docplex.mp.LinearConstraint[](x803-x827,LE,0),
#  docplex.mp.LinearConstraint[](x804-x828,LE,0),
#  docplex.mp.LinearConstraint[](x805-x829,LE,0),
#  docplex.mp.LinearConstraint[](x806-x830,LE,0),
#  docplex.mp.LinearConstraint[](x807-x831,LE,0),
#  docplex.mp.LinearConstraint[](x808-x832,LE,0),
#  docplex.mp.LinearConstraint[](x809-x833,LE,0),
#  docplex.mp.LinearConstraint[](x810-x834,LE,0),
#  docplex.mp.LinearConstraint[](x811-x835,LE,0),
#  docplex.mp.LinearConstraint[](x812-x836,LE,0),
#  docplex.mp.LinearConstraint[](x813-x837,LE,0),
#  docplex.mp.LinearConstraint[](x814-x838,LE,0),
#  docplex.mp.LinearConstraint[](x815-x839,LE,0),
#  docplex.mp.LinearConstraint[](x816-x840,LE,0)]

# %% [markdown]
# #### Solve with Decision Optimization
#
# Depending on the size of the problem, the solve stage might fail and require the Commercial Edition of CPLEX engines, which is included in the premium environments in IBM Cloud Pak for Data.
#
# You will get the best solution found after ***n*** seconds, because of a time limit parameter.

# %%
m.print_information()
# Out:
# Model: benders
#  - number of variables: 840
#    - binary=0, integer=24, continuous=816
#  - number of constraints: 850
#    - linear=850
#  - parameters: defaults
#  - objective: minimize
#  - problem type is: MILP

# %% [markdown]
# ### Step 2: Solve the problem with default CPLEX algorithm

# %%
msol = m.solve()
assert msol is not None, "model can't solve"
m.report()
# Out:
# WARNING: Number of workers has been reduced to 2 to comply with platform limitations.
# Version identifier: 22.1.1.0 | 2023-02-11 | 22d6266e5
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 2
# Found incumbent of value 494.000000 after 0.00 sec. (0.07 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 850 rows, 840 columns, and 2448 nonzeros.
# Reduced MIP has 24 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (1.14 ticks)
# Probing time = 0.00 sec. (0.10 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# Reduced MIP has 850 rows, 840 columns, and 2448 nonzeros.
# Reduced MIP has 24 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (1.41 ticks)
# Probing time = 0.00 sec. (0.10 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 2 threads.
# Root relaxation solution time = 0.01 sec. (0.59 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                          494.0000        0.0000           100.00%
# *     0     0      integral     0       45.0000       45.0000       36    0.00%
# Elapsed time = 0.05 sec. (4.69 ticks, tree = 0.00 MB, solutions = 2)
#
# Root node processing (before b&c):
#   Real time             =    0.05 sec. (4.73 ticks)
# Parallel b&c, 2 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.05 sec. (4.73 ticks)
# * model benders solved with objective = 45.000

# %% [markdown]
# #### Inspect the CPLEX Log.

# %% [markdown]
# If you inspect the CPLEX, you will see that it is a very standard log.
# CPLEX needed 63 iterations to solve it.

# %%
obj1 = m.objective_value

# %% [markdown]
# ### Step 3: Apply a Benders strategy

# %% [markdown]
# CPLEX implements a default Benders decomposition in certain situations.
#
# If you want CPLEX to apply a Benders strategy as it solves your problem, but you do not specify cpxBendersPartition annotations yourself, CPLEX puts all integer variables in master and continuous variables into subproblems.
# If there are no integer variables in your model, or if there are no continuous variables in your model, CPLEX raises an error stating that it cannot automatically decompose the model to apply a Benders strategy.

# %% [markdown]
# You just need to set the Benders strategy parameter.

# %% [markdown]
# CPLEX supports 4 values for this parameter, from -1 to 3:
# * OFF (default value) will ignore Benders.
# * AUTO, USER, WORKERS, FULL will enable Benders.
#
# Refer to the CPLEX documentation to understand the differences between the 4 values that trigger it.

# %%
m.parameters.benders.strategy = 3

# %%
m.print_information()
# Out:
# Model: benders
#  - number of variables: 840
#    - binary=0, integer=24, continuous=816
#  - number of constraints: 850
#    - linear=850
#  - parameters:
#      parameters.benders.strategy = 3
#  - objective: minimize
#  - problem type is: MILP

# %% [markdown]
# Call cplex solve, but with the <i>clean_before_solve</i> flag to ignore everything about the previous solve and solution.

# %%
msol = m.solve(clean_before_solve=True)
assert msol is not None, "model can't solve"
m.report()
# Out:
# WARNING: Number of workers has been reduced to 2 to comply with platform limitations.
# Version identifier: 22.1.1.0 | 2023-02-11 | 22d6266e5
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 2
# CPXPARAM_Benders_Strategy                        3
# Found incumbent of value 494.000000 after 0.00 sec. (0.07 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 850 rows, 840 columns, and 2448 nonzeros.
# Reduced MIP has 24 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (1.00 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 850 rows, 840 columns, and 2448 nonzeros.
# Reduced MIP has 24 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (0.93 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
#       0     0        0.0000            494.0000    Benders: 3        0  100.00%
#       0     0        5.0000            494.0000    Benders: 6        3   98.99%
#       0     0       11.6667            494.0000    Benders: 2       10   97.64%
#       0     0       15.0556            494.0000    Benders: 1       13   96.95%
#       0     0       15.5000            494.0000   Benders: 13       14   96.86%
#       0     0       31.3929            494.0000    Benders: 4       36   93.65%
#       0     0       32.6762            494.0000    Benders: 2       45   93.39%
#       0     0       33.6429            494.0000    Benders: 9       47   93.19%
#       0     0       41.2143            494.0000    Benders: 5       59   91.66%
#       0     0       45.0000            494.0000       45.0000       64   90.89%
# Tried aggregator 1 time.
# MIP Presolve eliminated 8 rows and 0 columns.
# Reduced MIP has 22 rows, 58 columns, and 54 nonzeros.
# Reduced MIP has 24 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (0.02 ticks)
# Probing time = 0.00 sec. (0.00 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 22 rows, 58 columns, and 54 nonzeros.
# Reduced MIP has 24 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (0.02 ticks)
# Probing time = 0.00 sec. (0.00 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 2 threads.
# Root relaxation solution time = 0.00 sec. (0.03 ticks)
# *     0+    0                           47.0000       45.0000             4.26%
#       0     0       45.0000     5       47.0000       45.0000       85    4.26%
# *     0     0      integral     0       45.0000       Cuts: 6       87    0.00%
#       0     0        cutoff             45.0000       45.0000       87    0.00%
# Elapsed time = 0.22 sec. (11.40 ticks, tree = 0.01 MB, solutions = 1)
#
# Benders cuts applied:  33
# Mixed integer rounding cuts applied:  1
# Gomory fractional cuts applied:  2
#
# Root node processing (before b&c):
#   Real time             =    0.23 sec. (11.40 ticks)
# Parallel b&c, 2 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.23 sec. (11.40 ticks)
# * model benders solved with objective = 45.000

# %% [markdown]
# #### Inspect the CPLEX Log.

# %% [markdown]
# Inspect the CPLEX log: you can now see that the logs are different and you can see the message
# <code>
# Benders cuts applied:  3
# </code>
# which proves CPLEX applied successfully
#
# You can see that CPLEX needed only 61 cumulative iterations, while it needed 63 previously.

# %%
obj2 = m.objective_value

# %% [markdown]
# ### Step 4: Use the CPLEX annotations to guide CPLEX in your Benders decomposition

# %%
m.parameters.benders.strategy = 1

# %% [markdown]
# Settings Benders annotation in docplex is very simple.
# You just need to use the <i>benders_annotation</i> property available on variables and constraints to state which worker they belong to.

# %%
for i in R2:
    for j in R1:
        X[i,j].benders_annotation =  i%2

# %%
m.print_information()
# Out:
# Model: benders
#  - number of variables: 840
#    - binary=0, integer=24, continuous=816
#  - number of constraints: 850
#    - linear=850
#  - annotations: 816
#    - variables: 816
#  - parameters:
#      parameters.benders.strategy = 1
#  - objective: minimize
#  - problem type is: MILP

# %%
msol = m.solve(clean_before_solve=True)
assert msol is not None, "model can't solve"
m.report()
# Out:
# WARNING: Number of workers has been reduced to 2 to comply with platform limitations.
# Version identifier: 22.1.1.0 | 2023-02-11 | 22d6266e5
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 2
# CPXPARAM_Benders_Strategy                        1
# Found incumbent of value 494.000000 after 0.00 sec. (0.07 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 850 rows, 840 columns, and 2448 nonzeros.
# Reduced MIP has 24 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (1.00 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 850 rows, 840 columns, and 2448 nonzeros.
# Reduced MIP has 24 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.93 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
#       0     0       24.0000            494.0000    Benders: 1       21   95.14%
#       0     0       26.4615            494.0000    Benders: 1       25   94.64%
#       0     0       30.7500            494.0000    Benders: 1       31   93.78%
#       0     0       37.2500            494.0000    Benders: 1       35   92.46%
#       0     0       41.5000            494.0000    Benders: 1       39   91.60%
#       0     0       41.9167            494.0000    Benders: 1       41   91.51%
#       0     0       43.8333            494.0000    Benders: 1       44   91.13%
#       0     0       44.6500            494.0000    Benders: 1       46   90.96%
#       0     0       44.7500            494.0000    Benders: 1       48   90.94%
#       0     0       44.9405            494.0000    Benders: 1       53   90.90%
#       0     0       44.9804            494.0000    Benders: 1       58   90.89%
#       0     0       45.0000            494.0000       45.0000       59   90.89%
# Tried aggregator 1 time.
# Reduced MIP has 430 rows, 433 columns, and 1271 nonzeros.
# Reduced MIP has 24 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (0.43 ticks)
# Probing time = 0.00 sec. (0.06 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 430 rows, 433 columns, and 1271 nonzeros.
# Reduced MIP has 24 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.42 ticks)
# Probing time = 0.00 sec. (0.06 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 2 threads.
# Root relaxation solution time = 0.00 sec. (0.29 ticks)
# *     0+    0                           47.0000       45.0000             4.26%
#       0     0       45.0000     1       47.0000       45.0000       78    4.26%
# *     0+    0                           46.0000       45.0000             2.17%
# *     0     0      integral     0       45.0000       Cuts: 5       80    0.00%
#       0     0        cutoff             45.0000       45.0000       80    0.00%
# Elapsed time = 0.14 sec. (15.97 ticks, tree = 0.01 MB, solutions = 2)
#
# Benders cuts applied:  7
# Mixed integer rounding cuts applied:  2
# Gomory fractional cuts applied:  1
#
# Root node processing (before b&c):
#   Real time             =    0.15 sec. (16.05 ticks)
# Parallel b&c, 2 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.15 sec. (16.05 ticks)
# * model benders solved with objective = 45.000

# %% [markdown]
# #### Inspect the CPLEX Log.

# %% [markdown]
# Inspect the CPLEX log: you can see that you now need only 57 cumulative iterations instead of 61 with default Benders and 63 with no Benders.
# If you look at the <i>Best Bound</i> column, you will also see that the listed sub problems are not the same as CPLEX applied the decomposition provided by the annotations.

# %%
obj3 = m.objective_value

# %%
assert (obj1 == obj2) and (obj2 == obj3)

# %% [markdown]
# ## Summary
#
#
# You have learned how to set up and use the IBM Decision Optimization CPLEX Modeling for Python to formulate a Mathematical Programming model and apply a Benders decomposition.

# %% [markdown]
# #### References
# * <a href="https://rawgit.com/IBMDecisionOptimization/docplex-doc/master/docs/index.html" target="_blank" rel="noopener noreferrer">Decision Optimization CPLEX Modeling for Python documentation</a>
# * <a href="https://dataplatform.cloud.ibm.com/docs/content/wsj/getting-started/welcome-main.html?context=cpdaas" target="_blank" rel="noopener noreferrer">IBM Cloud Pak for Data as a Service documentation</a>
# * <a href="https://dataplatform.cloud.ibm.com/docs/content/wsj/getting-started/welcome-main.html?context=wx" target="_blank" rel="noopener noreferrer">IBM watsonx.ai documentation</a>

# %% [markdown]
# <hr>
# Copyright © 2017-2024. This notebook and its source code are released under the terms of the MIT License.
