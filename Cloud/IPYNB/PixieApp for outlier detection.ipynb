# %% [markdown]
# <div style="background:#F5F7FA; height:100px; padding: 2em; font-size:14px;">
# <span style="font-size:18px;color:#152935;">Want to do more?</span><span style="border: 1px solid #3d70b2;padding: 15px;float:right;margin-right:40px; color:#3d70b2; "><a href="https://ibm.co/wsnotebooks" target="_blank" style="color: #3d70b2;text-decoration: none;">Sign Up</a></span><br>
# <span style="color:#5A6872;"> Try out this notebook with your free trial of IBM Watson Studio.</span>
# </div>

# %% [markdown]
# # PixieApp for Outlier Detection
# ### Demonstrated with a Boston Public Schools data set
#
#
# PixieApps from the PixieDust package are a great tool to facilitate data exploration. The PixieApp for outlier detection can currently run two unsupervised machine learning models and visualize their output. It's a work in progress, and the goal is also to make it more flexible to fit the needs of different data types.
#
# The next step after this notebook will be to allow users to interact more with the output and to tune the outlier algorithms inside the PixieApp.
#
# This notebook uses a data set composed of facility and administrative information for Boston Public Schools (BPS) from <a href="https://data.boston.gov" target="_blank" rel="noopener no referrer">Analyze Boston</a> to answer these two questions:
#
# 1. What is the relationship between square footage of a school, enrollment, location, and energy costs? <br/>
# Can we predict how much a school will pay in energy costs with facility data?
#
# 2. How often do Principals live in the zip code of their school?
# Can we predict how far from a school the principal will live using demographic information for zip codes and principal total earnings?
#
# This notebook runs on Python with Spark 2.1.

# %% [markdown]
# ## Table of contents
# 1. [Install PixieDust](#install)
# 2. [Create the Boston Public Schools data set](#createdataset)
# 3. [Create the PixieApp](#createpixieapp)
# 4. [Run the PixieApp](#runpixieapp)
# 5. [Explore data in two-dimensions](#explore)
# 6. [Next steps](#nextsteps)

# %% [markdown]
# ## 1. Install PixieDust<a class="anchor" id="install"></a>
#
# First, make sure PixieDust and scikit-learn are up-to-date.

# %%
# !pip install --user --upgrade pixiedust
# !pip install --user --upgrade scikit-learn
# !pip install --user --upgrade bokeh

# %%
import pixiedust
import numpy as np
import matplotlib.pyplot as plt
import sklearn.ensemble
import pandas as pd
from sklearn import svm
from pyspark.mllib.stat import Statistics
from pyspark.mllib.clustering import *
import pyspark.sql.functions as fn
from re import sub
from decimal import Decimal
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.6</span>
#         </div>
# <div>Warning: You are not running the latest version of PixieDust. Current is 1.1.6, Latest is 1.1.7.1</div>
#                 <div>Please copy and run the following command in a new cell to upgrade: <span style="background-color:#ececec;font-family:monospace;padding:0 5px">!pip install --user --upgrade pixiedust</span></div>
# <div>Please restart kernel after upgrading.</div>

# %% [markdown]
# ## 2. Create the Boston Public Schools data set<a class="anchor" id="createdataset"></a>
#
# 2.1 [Import the BuildBPS data set](#buildbps)<br/>
# 2.2 [Link BuildBPS data set to the Employee Earnings data set](#linkdataset)<br/>
# 2.3 [Merge the employee information with the school data set](#merge)<br/>
# 2.4 [Format variables](#formatvar)
#
#
# ### 2.1 Import the BuildBPS data set<a class="anchor" id="buildbps"></a>
#
# The backbone of the Boston Public Schools (BPS) data set, BuildBPS, includes:
#
# - Latitude and longitude for schools in BPS
# - Energy costs
# - Facility information
# - Enrollment information
# - Administration information
#
# Principal name is separated into first and last name to link to the Employee Earnings data set.

# %%
#Import the data and transform to Pandas. Pixiedust works with Spark dataframes, but unfortunately, scikitlearn will not.
schools = pixiedust.sampleData("https://data.boston.gov/dataset/b2c5a9d3-609d-49ec-906c-b0e850a8d62a/resource/33c5f44a-3c67-4390-a1d5-1bf018e4728c/download/buildbps.csv")
schools = schools.toPandas()

#Pull a subset of variables of interest
schools = schools[['SMMA_Identifier', 'BPS_School_Name', 'BPS_Address', 'SMMA_latitude', 'SMMA_longitude', 'BPS_Grades_Offered', 'SMMA_Site_SF', 'DOE_Total', ' BPS_Total_Energy_Cost ', 'BPS_Principal']]

#Separate the principals' first and last names to aid linking
def findFirstName(name):
    if isinstance(name, basestring):
        if 'Dr' in name:
            name = name.split('. ')[-1]
        firstname = name.split(' ')[0]
    else:
        firstname = name
    return firstname

schools['Principal_Firstname'] = schools['BPS_Principal'].apply(lambda x : findFirstName(x))

def findLastName(name):
#takes the last word before an optional comma, which should be the last name in this dataset
    if isinstance(name, basestring):
        name = name.split(',')[0]
        if isinstance(name, basestring):
            lastname = name.split(' ')[-1]
            if lastname == 'Jr.':
                lastname = name.split(' ')[-2]
        else:
            lastname = name
    else:
        lastname = name
    return lastname

schools['Principal_Lastname'] = schools['BPS_Principal'].apply(lambda x : findLastName(x))

#Print the first 5 rows to get a look at the data
schools.head()
# Out:
# Downloading 'https://data.boston.gov/dataset/b2c5a9d3-609d-49ec-906c-b0e850a8d62a/resource/33c5f44a-3c67-4390-a1d5-1bf018e4728c/download/buildbps.csv' from https://data.boston.gov/dataset/b2c5a9d3-609d-49ec-906c-b0e850a8d62a/resource/33c5f44a-3c67-4390-a1d5-1bf018e4728c/download/buildbps.csv
# Downloaded 175213 bytes
# Creating pySpark DataFrame for 'https://data.boston.gov/dataset/b2c5a9d3-609d-49ec-906c-b0e850a8d62a/resource/33c5f44a-3c67-4390-a1d5-1bf018e4728c/download/buildbps.csv'. Please wait...
# Loading file using 'SparkSession'
# Successfully created pySpark DataFrame for 'https://data.boston.gov/dataset/b2c5a9d3-609d-49ec-906c-b0e850a8d62a/resource/33c5f44a-3c67-4390-a1d5-1bf018e4728c/download/buildbps.csv'
#   SMMA_Identifier                       BPS_School_Name  \
# 0             031              Adams, Samuel Elementary
# 1             078    Alighieri, Dante Montessori School
# 2            045A            Another Course to College*
# 3             012  Baldwin Early Learning Pilot Academy
# 4             087             Bates, Phineas Elementary
#
#                             BPS_Address  SMMA_latitude  SMMA_longitude  \
# 0  165 Webster St East Boston, MA 02128      42.365553      -71.034917
# 1  37 Gove Street East Boston, MA 02128      42.371565      -71.037608
# 2   20 Warren Street Brighton, MA 02135      42.350354      -71.145582
# 3       121 Corey Rd Brighton, MA 02135      42.342037      -71.140529
# 4     426 Beech St Roslindale, MA 02131      42.277663      -71.135353
#
#   BPS_Grades_Offered  SMMA_Site_SF DOE_Total  BPS_Total_Energy_Cost   \
# 0               K0-5         40680       302             $71,740.00
# 1               K0-5         22039        90             $13,714.00
# 2               9-12         83088       237            $128,398.00
# 3               K0-1         29990       142             $26,472.00
# 4               K1-5         67077       297             $35,538.00
#
#         BPS_Principal Principal_Firstname Principal_Lastname
# 0        Hannah Irvin              Hannah              Irvin
# 1        Mayra Cuevas               Mayra             Cuevas
# 2  Lisa Gilbert-Smith                Lisa      Gilbert-Smith
# 3          Tavia Mead               Tavia               Mead
# 4          Kelly Hung               Kelly               Hung

# %% [markdown]
# ### 2.2 Link BuildBPS to the Employee Earnings data set<a class="anchor" id="linkdataset"></a>
#
# To make it more interesting, link the BuildBPS data set to get *principal earnings* and *zip code* from the Employee Earnings data set. Because principal name is the only available linking variable, this gets a bit messy. <br/>
# This data set includes:
# - Employee names
# - Departments
# - Titles
# - Earnings
# - Zip code

# %%
#Import the data and transform to Pandas
employees = pixiedust.sampleData("https://data.boston.gov/dataset/418983dc-7cae-42bb-88e4-d56f5adcf869/resource/2ff6343f-850d-46e7-98d1-aca79b619fd6/download/employee-earnings-report-2015.csv")
employees = employees.toPandas()

#Keep variables of interest
employees = employees[['NAME', 'DEPARTMENT_NAME', 'TITLE', 'TOTAL EARNINGS', 'POSTAL']]

#Keep employees with title containing "headmaster" or "principal"
employees = employees[employees['TITLE'].str.contains('headmaster|principal', case = False)]

#Separate first and last names for merging with the key dataset
employees['Principal_Lastname'] = employees['NAME'].str.split(',', 1, expand = True)[0]
employees['Principal_Firstname'] = employees['NAME'].str.split(',', 1, expand = True)[1]

#Print the first 5 rows to get a look at the data
employees.head()
# Out:
# Downloading 'https://data.boston.gov/dataset/418983dc-7cae-42bb-88e4-d56f5adcf869/resource/2ff6343f-850d-46e7-98d1-aca79b619fd6/download/employee-earnings-report-2015.csv' from https://data.boston.gov/dataset/418983dc-7cae-42bb-88e4-d56f5adcf869/resource/2ff6343f-850d-46e7-98d1-aca79b619fd6/download/employee-earnings-report-2015.csv
# Downloaded 2712454 bytes
# Creating pySpark DataFrame for 'https://data.boston.gov/dataset/418983dc-7cae-42bb-88e4-d56f5adcf869/resource/2ff6343f-850d-46e7-98d1-aca79b619fd6/download/employee-earnings-report-2015.csv'. Please wait...
# Loading file using 'SparkSession'
# Successfully created pySpark DataFrame for 'https://data.boston.gov/dataset/418983dc-7cae-42bb-88e4-d56f5adcf869/resource/2ff6343f-850d-46e7-98d1-aca79b619fd6/download/employee-earnings-report-2015.csv'
#                         NAME               DEPARTMENT_NAME  \
# 156         Ake,Natalie Diaz             Ellison/Parks EES
# 529   Anoh,Jean-Dominique H.          Lyon Pilot High 9-12
# 793          Azores,Sheila M  BPS Alternative Education HS
# 801           Babio,Phanenca        BPS MPH\Health Academy
# 1193    Becker,Jeffrey Brian                 Green Academy
#
#                      TITLE TOTAL EARNINGS POSTAL Principal_Lastname  \
# 156   Principal Elementary     $123698.49  02131                Ake
# 529             Headmaster     $129688.40  01721               Anoh
# 793             Headmaster     $135919.81  02126             Azores
# 801        Asst Headmaster      $73619.11  02124              Babio
# 1193       Asst Headmaster      $97950.42  02176             Becker
#
#      Principal_Firstname
# 156         Natalie Diaz
# 529    Jean-Dominique H.
# 793             Sheila M
# 801             Phanenca
# 1193       Jeffrey Brian

# %% [markdown]
# ### 2.3 Merge the employee information with the school data set<a class="anchor" id="merge"></a>
#
# Next, merge the employee information into the school data set. First names differ slightly and nicknames are sometimes used (for example, "Rob" vs. "Robert"), so we match on last name and first three letters of first name.
#
# To make this more accurate in the future, consider using a fuzzy matching algorithm. 40 schools (about 30% of the data set) are lost in the matching, either due to missing principal name in the BuildBPS data set (11) or inadequate matching (29).

# %%
#Merge on last name
schools_df = pd.merge(schools, employees, on = 'Principal_Lastname')

#Keep those matches that match in the first 3 letters of first name
schools_df['Firstname_match'] = schools_df['Principal_Firstname_x'].apply(lambda x : x[0:3].lower())
schools_df['Principal_Firstname_y'] = schools_df['Principal_Firstname_y'].apply(lambda x: x.lower())
schools_df['correct_name'] = schools_df.apply(lambda x: x['Firstname_match'] in x['Principal_Firstname_y'], axis = 1)
schools_df = schools_df[schools_df['correct_name']]

schools_df.describe(include = 'all')
# Out:
#        SMMA_Identifier           BPS_School_Name  \
# count               98                        98
# unique              98                        98
# top                124  Guild, Curtis Elementary
# freq                 1                         1
# mean               NaN                       NaN
# std                NaN                       NaN
# min                NaN                       NaN
# 25%                NaN                       NaN
# 50%                NaN                       NaN
# 75%                NaN                       NaN
# max                NaN                       NaN
#
#                               BPS_Address  SMMA_latitude  SMMA_longitude  \
# count                                  98      98.000000       98.000000
# unique                                 95            NaN             NaN
# top     40 Armington St Allston, MA 02134            NaN             NaN
# freq                                    2            NaN             NaN
# mean                                  NaN      42.321021      -71.090898
# std                                   NaN       0.037020        0.037956
# min                                   NaN      42.233938      -71.174549
# 25%                                   NaN      42.288235      -71.117920
# 50%                                   NaN      42.325601      -71.089480
# 75%                                   NaN      42.347923      -71.064721
# max                                   NaN      42.391629      -71.004256
#
#        BPS_Grades_Offered    SMMA_Site_SF DOE_Total  BPS_Total_Energy_Cost   \
# count                  98       97.000000        98                      98
# unique                 26             NaN        89                      91
# top                  9-12             NaN       302                   $-
# freq                   18             NaN         3                       4
# mean                  NaN   149100.247423       NaN                     NaN
# std                   NaN   250486.793801       NaN                     NaN
# min                   NaN     5328.000000       NaN                     NaN
# 25%                   NaN    49940.000000       NaN                     NaN
# 50%                   NaN    73819.000000       NaN                     NaN
# 75%                   NaN   152690.000000       NaN                     NaN
# max                   NaN  1938398.000000       NaN                     NaN
#
#        BPS_Principal Principal_Firstname_x Principal_Lastname        NAME  \
# count             98                    98                 98          98
# unique            95                    93                 95          95
# top         Simon Ho                 Simon           Sheridan  Ho,Simon S
# freq               2                     2                  2           2
# mean             NaN                   NaN                NaN         NaN
# std              NaN                   NaN                NaN         NaN
# min              NaN                   NaN                NaN         NaN
# 25%              NaN                   NaN                NaN         NaN
# 50%              NaN                   NaN                NaN         NaN
# 75%              NaN                   NaN                NaN         NaN
# max              NaN                   NaN                NaN         NaN
#
#             DEPARTMENT_NAME                 TITLE TOTAL EARNINGS POSTAL  \
# count                    98                    98             98     98
# unique                   95                     4             92     49
# top     Warren/Prescott K-8  Principal Elementary     $135338.96  02131
# freq                      2                    45              2      8
# mean                    NaN                   NaN            NaN    NaN
# std                     NaN                   NaN            NaN    NaN
# min                     NaN                   NaN            NaN    NaN
# 25%                     NaN                   NaN            NaN    NaN
# 50%                     NaN                   NaN            NaN    NaN
# 75%                     NaN                   NaN            NaN    NaN
# max                     NaN                   NaN            NaN    NaN
#
#        Principal_Firstname_y Firstname_match correct_name
# count                     98              98           98
# unique                    95              76          NaN
# top                  simon s             mar          NaN
# freq                       2               5          NaN
# mean                     NaN             NaN            1
# std                      NaN             NaN            0
# min                      NaN             NaN         True
# 25%                      NaN             NaN            1
# 50%                      NaN             NaN            1
# 75%                      NaN             NaN            1
# max                      NaN             NaN         True

# %% [markdown]
# ### 2. 4 Format variables<a class="anchor" id="formatvar"></a>
#
# Some numeric variables, like earnings and energy cost, are saved as string and need to be converted to numeric.

# %%
#Remove schools with missing energy cost (4 schools)
schools_df['no_energy_cost'] = schools_df.apply(lambda x: '-' in x[' BPS_Total_Energy_Cost '], axis = 1)
schools_df = schools_df[~schools_df['no_energy_cost']]

#Restore numeric fields stored as strings to their former glory
schools_df[' BPS_Total_Energy_Cost '] = schools_df[' BPS_Total_Energy_Cost '].apply(lambda x: float(sub(r'[^\d.]', '', x)))
schools_df['TOTAL EARNINGS'] = schools_df['TOTAL EARNINGS'].apply(lambda x: float(sub(r'[^\d.]', '', x)))
schools_df['DOE_Total'] = schools_df['DOE_Total'].apply(lambda x: int(x))

#Drop intermediate linking and boolean fields
schools_df = schools_df[['SMMA_Identifier', 'BPS_School_Name', 'BPS_Address', 'SMMA_latitude', 'SMMA_longitude', 'BPS_Grades_Offered', 'SMMA_Site_SF', 'DOE_Total', ' BPS_Total_Energy_Cost ', 'BPS_Principal', 'TOTAL EARNINGS', 'POSTAL', 'TITLE']]

#Summary statistics:
schools_df.describe(include = 'all')
# Out:
#        SMMA_Identifier           BPS_School_Name  \
# count               94                        94
# unique              94                        94
# top                124  Guild, Curtis Elementary
# freq                 1                         1
# mean               NaN                       NaN
# std                NaN                       NaN
# min                NaN                       NaN
# 25%                NaN                       NaN
# 50%                NaN                       NaN
# 75%                NaN                       NaN
# max                NaN                       NaN
#
#                                  BPS_Address  SMMA_latitude  SMMA_longitude  \
# count                                     94      94.000000       94.000000
# unique                                    91            NaN             NaN
# top     200 Heath St Jamaica Plain, MA 02130            NaN             NaN
# freq                                       2            NaN             NaN
# mean                                     NaN      42.321175      -71.090184
# std                                      NaN       0.037654        0.038221
# min                                      NaN      42.233938      -71.174549
# 25%                                      NaN      42.286505      -71.117920
# 50%                                      NaN      42.325601      -71.087421
# 75%                                      NaN      42.348312      -71.064081
# max                                      NaN      42.391629      -71.004256
#
#        BPS_Grades_Offered    SMMA_Site_SF    DOE_Total  \
# count                  94       93.000000    94.000000
# unique                 25             NaN          NaN
# top                  9-12             NaN          NaN
# freq                   16             NaN          NaN
# mean                  NaN   130883.010753   445.840426
# std                   NaN   213274.973178   354.550671
# min                   NaN     5328.000000     0.000000
# 25%                   NaN    49940.000000   231.250000
# 50%                   NaN    73819.000000   370.500000
# 75%                   NaN   148351.000000   529.000000
# max                   NaN  1938398.000000  2439.000000
#
#          BPS_Total_Energy_Cost  BPS_Principal  TOTAL EARNINGS POSTAL  \
# count                 94.000000            94       94.000000     94
# unique                      NaN            91             NaN     46
# top                         NaN      Simon Ho             NaN  02131
# freq                        NaN             2             NaN      8
# mean              140104.308511           NaN   124338.520745    NaN
# std               134927.919666           NaN    19407.632907    NaN
# min                 4820.000000           NaN    56649.970000    NaN
# 25%                41619.250000           NaN   118110.970000    NaN
# 50%                77514.000000           NaN   127543.455000    NaN
# 75%               204774.000000           NaN   135814.197500    NaN
# max               589219.000000           NaN   160182.780000    NaN
#
#                        TITLE
# count                     94
# unique                     4
# top     Principal Elementary
# freq                      45
# mean                     NaN
# std                      NaN
# min                      NaN
# 25%                      NaN
# 50%                      NaN
# 75%                      NaN
# max                      NaN

# %% [markdown]
# ## 3. Create the PixieApp<a class="anchor" id="createpixieapp"></a>
#
# There are currently two options for algorithms:
#
# - Isolation Forest
#     * <a href="http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.IsolationForest.html" target="_blank" rel="noopener no referrer">Sklearn documentation</a>
#     * <a href="https://cs.nju.edu.cn/zhouzh/zhouzh.files/publication/icdm08b.pdf" target="_blank" rel="noopener no referrer">Paper</a>
#
#
# - One Class SVM with RBF Kernel
#     * <a href="http://scikit-learn.org/stable/modules/generated/sklearn.svm.OneClassSVM.html" target="_blank" rel="noopener no referrer">Sklearn documentation</a>
#     * <a href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3041295/" target="_blank" rel="noopener no referrer">An academic application example</a>
#
# In each case, the PixieApp generates a binary column (*is_outlier_iforest* or *is_outlier_svm*) indicating how the algorithm classified the BPS school. Click **map** to plot the schools on a map. Outlier schools are dark blue.

# %%
from pixiedust.display.app import *

@PixieApp
class TestPixieApp:


    @route()
    def main(self):
        return"""
            <input pd_options="iForest_clicked=true"
            type="button" value = "Outliers by Isolation Forest">
            <input pd_options="SVM_clicked=true"
            type="button" value = "Outliers by One-Class Support Vector Machine">          
            """
    
    @route(iForest_clicked="true")
    def iForest_clicked(self):
        return """
            <div id="target{{prefix}}"> 
            <input pd_options="handlerId=dataframe"
            pd_entity = "trainIForest(a.pixieapp_entity, 256)"
            type="button" value="Table">
            <input pd_options="handlerId=mapView;aggregation=SUM;rowCount=500;mapboxtoken=pk.eyJ1IjoidHJ1ZGFrZSIsImEiOiJjajN5c29wbWUwMDQwMnZvZWNmZWxiNmNuIn0.gFeF4D4TkU2Tro-EB7HF0w;valueFields=is_outlier_iforest;rendererId=mapbox"
            pd_entity = "trainIForest(a.pixieapp_entity, 256)"
            type="button" value="Map">
            </div>
            """
    
    def numeric_columns(self, df):
        return list(df.select_dtypes(include=[np.number]).columns.values) 

    def trainIForest(self, df, maxsample_input):
        # fit an isolation forest (more adapted to large-dimensional settings)
        if type(df) is pyspark.sql.dataframe.DataFrame: 
            df = df.toPandas()
        
        # fits on all numeric features
        numeric_columns = list(df.select_dtypes(include=[np.number]).columns.values) 
        df_num = df[numeric_columns]

        # fill missing values with column mean
        df_num = df_num.fillna(df.mean())

        clf = sklearn.ensemble.IsolationForest(max_samples=maxsample_input)
        clf.fit(df_num)
        y_pred_train = clf.predict(df_num)
        df['is_outlier_iforest'] = y_pred_train
        df['is_outlier_iforest'] = df['is_outlier_iforest'].map({1: 0, -1: 1})
        return df.sort_values('is_outlier_iforest', ascending = False)

    @route(SVM_clicked="true")
    def SVM_clicked(self):
        return """
            <div id="target{{prefix}}">
            <div id="target{{prefix}}"> 
            <input pd_options="handlerId=dataframe"
            pd_entity = "trainSVM(a.pixieapp_entity)"
            type="button" value="Table">
            <input pd_options="handlerId=mapView;aggregation=SUM;rowCount=500;mapboxtoken=pk.eyJ1IjoidHJ1ZGFrZSIsImEiOiJjajN5c29wbWUwMDQwMnZvZWNmZWxiNmNuIn0.gFeF4D4TkU2Tro-EB7HF0w;valueFields=is_outlier_svm;rendererId=mapbox"
            pd_entity = "trainSVM(a.pixieapp_entity)"
            type="button" value="Map">
            </div>
            </div>
            """
    def trainSVM(self, df):
        # fit a one-class support vector machine 
        if type(df) is pyspark.sql.dataframe.DataFrame: 
            df = df.toPandas()
                
        # fits on all numeric columns
        numeric_columns = list(df.select_dtypes(include=[np.number]).columns.values) 
        df_num = df[numeric_columns]
        
        # fill missing values with the mean
        df_num = df_num.fillna(df.mean())
        
        clf = svm.OneClassSVM(nu=0.2, kernel="rbf", gamma = .01)
        clf.fit(df_num)
        y_pred_train = clf.predict(df_num)
        df['is_outlier_svm'] = y_pred_train
        df['is_outlier_svm'] = df['is_outlier_svm'].map({1: 0, -1: 1})
        return df.sort_values('is_outlier_svm', ascending = False)
    
a = TestPixieApp()

# %% [markdown]
# ## 4. Run the PixieApp<a class="anchor" id="runpixieapp"></a>

# %%
a.run(schools_df, runInDialog='false')
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>

# %% [markdown]
# The first screen of the PixieApp looks like this:
# <img width="545" alt="pixieapp1" src="https://user-images.githubusercontent.com/28162685/28128056-6d84f3d2-66fc-11e7-9f6b-2fecec3a87e9.png">

# %% [markdown]
# Click **Isolation Forest** to display the following screen:
# <img width="197" alt="pixieapp2" src="https://user-images.githubusercontent.com/28162685/28128070-7a5f24e2-66fc-11e7-8096-fe60b7a119df.png">

# %% [markdown]
# The map shows a map of all the BPS schools, with outliers in dark blue:
# <img width="993" alt="iforest_map" src="https://user-images.githubusercontent.com/28162685/28128035-55574ba2-66fc-11e7-881c-35303b3156e6.png">

# %% [markdown]
# Following the same path for One Class SVM, it yields almost twice as many outliers in this data set. The map looks like this:
# <img width="996" alt="svm_map" src="https://user-images.githubusercontent.com/28162685/28128046-60b2e164-66fc-11e7-962f-89e5261ed807.png">

# %% [markdown]
# ## 5. Explore the data in two-dimensions<a class="anchor" id="explore"></a>
#
# Now that the PixieApp has identified outliers, you can look at the data in one or two dimensions using PixieDust.
#
# Use PixieDust to display *schools_df* and navigate to scatterplot. This example uses "bokeh" as the renderer, and  the key and value fields are switched out while using *is_outlier_iforest* as color. PixieDust makes it very easy to explore scatterplots with different variables quickly.
#
# ### Isolation Forest
#
# First, look at *Total Energy Cost* against *Square Feet*. It's clear that IForest labeled two schools with very large square footage as outliers.

# %%
display(schools_df)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#             IForest: Energy Cost vs. Square Feet
#         </div>
#     <div id="chartFigure9e050b16" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-9e050b16")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"6e55fffd-e8f4-455c-97de-fda297b9ffc5":{"roots":{"references":[{"attributes":{},"id":"e36dab0c-ba5f-430e-bfa3-bd1749040b60","type":"LinearScale"},{"attributes":{"dimension":1,"grid_line_alpha":{"value":0.3},"plot":{"id":"ebcf0a3d-d547-4c4b-a1ed-cc0de3034519","subtype":"Figure","type":"Plot"},"ticker":{"id":"381b83ad-5ade-493a-8aae-9b76b8075156","type":"BasicTicker"}},"id":"831949e1-c961-4204-b083-9caf87388291","type":"Grid"},{"attributes":{},"id":"5fb1dc65-3859-4a97-be08-8a719a8caaf1","type":"HelpTool"},{"attributes":{"axis_label":"SMMA_Site_SF","formatter":{"id":"70a9c533-915c-4e2a-907a-1aa224ab3f2a","type":"BasicTickFormatter"},"plot":{"id":"ebcf0a3d-d547-4c4b-a1ed-cc0de3034519","subtype":"Figure","type":"Plot"},"ticker":{"id":"381b83ad-5ade-493a-8aae-9b76b8075156","type":"BasicTicker"}},"id":"f0350730-8dbf-4ed5-9da8-bac4493d82c0","type":"LinearAxis"},{"attributes":{"below":[{"id":"85383831-0283-4730-a326-92b9411b7039","type":"LinearAxis"}],"left":[{"id":"f0350730-8dbf-4ed5-9da8-bac4493d82c0","type":"LinearAxis"}],"plot_height":490,"plot_width":985,"renderers":[{"id":"85383831-0283-4730-a326-92b9411b7039","type":"LinearAxis"},{"id":"04bef532-6f20-4538-a520-69d0c1529a2d","type":"Grid"},{"id":"f0350730-8dbf-4ed5-9da8-bac4493d82c0","type":"LinearAxis"},{"id":"831949e1-c961-4204-b083-9caf87388291","type":"Grid"},{"id":"afe6e24c-31ec-4e0c-8bc3-987e3963c2d1","type":"BoxAnnotation"},{"id":"af673ac0-31fb-46ca-9677-5cdef74b211f","type":"GlyphRenderer"}],"title":{"id":"84991037-b001-40a0-9998-7a4c7e5e47f6","type":"Title"},"toolbar":{"id":"6d649c55-8a44-4743-8572-b37ccde23f47","type":"Toolbar"},"x_range":{"id":"9007dcda-4b0a-4a89-ac3e-0676272cbd77","type":"DataRange1d"},"x_scale":{"id":"ad68d5f8-d6ac-42e5-8284-e1e7d73b55c2","type":"LinearScale"},"y_range":{"id":"e116d29f-2951-4cad-8a70-f5c7a1d96f15","type":"DataRange1d"},"y_scale":{"id":"e36dab0c-ba5f-430e-bfa3-bd1749040b60","type":"LinearScale"}},"id":"ebcf0a3d-d547-4c4b-a1ed-cc0de3034519","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"0faf94d7-be91-4d7e-b118-844911ed1213","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[22677.0,23087.0,24727.0,26016.0,26472.0,27295.0,28545.0,28675.0,28864.0,29238.0,30276.0,30642.0,31312.0,31722.0,34434.0,34816.0,35112.0,35538.0,35664.0,36477.0,39352.0,40195.0,41196.0,42889.0,44016.0,44427.0,44487.0,48574.0,49412.0,49960.0,50211.0,50430.0,52159.0,55451.0,55755.0,56361.0,58667.0,58923.0,60369.0,60892.0,66564.0,66961.0,68890.0,71740.0,74156.0,76582.0,78446.0,78471.0,83163.0,83813.0,86121.0,88215.0,90792.0,91080.0,105662.0,109068.0,109752.0,119624.0,122327.0,128398.0,137489.0,155336.0,156873.0,163584.0,178011.0,188508.0,202962.0,202962.0,203607.0,205163.0,214030.0,216619.0,230958.0,233067.0,233067.0,238785.0,280042.0,298000.0,308475.0,326262.0,327629.0,356842.0,364106.0,364494.0,379310.0,388092.0,388092.0,400250.0,415579.0,444236.0,484098.0,484098.0,589219.0],"y":[29932.0,33042.0,47958.0,48573.0,29990.0,38670.0,40000.0,54952.0,49940.0,5328.0,35445.0,69049.0,39227.0,79305.0,37850.0,45821.0,56006.0,67077.0,67138.0,69281.0,58932.0,73586.0,44999.0,35491.0,34336.0,58845.0,52800.0,52065.0,26000.0,8736.0,64004.0,102660.0,83598.0,47521.0,117393.0,60408.0,56384.0,175916.0,78914.0,72143.0,66327.0,38670.0,69377.0,40680.0,73819.0,82860.0,167794.0,58932.0,115536.0,43382.0,69502.0,66918.0,57329.0,19853.0,301553.0,148351.0,85562.0,145153.0,174997.0,83088.0,141611.0,117847.0,117847.0,117848.0,101387.0,24723.0,181714.0,181714.0,290048.0,282110.0,124571.0,194261.0,610119.0,159439.0,159439.0,220875.0,438649.0,128117.0,211748.0,119598.0,152690.0,403445.0,237737.0,157411.0,144255.0,247082.0,247082.0,84410.0,58974.0,260579.0,78697.0,78697.0,1938398.0]}},"id":"67947b3a-cdd5-476d-89d7-252a80c87186","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"67947b3a-cdd5-476d-89d7-252a80c87186","type":"ColumnDataSource"},"glyph":{"id":"93faa9b0-4cd9-4ed4-ab76-8cdf48f74e46","type":"Circle"},"hover_g ...

# %% [markdown]
# ![iforest_energycost_sqft](https://user-images.githubusercontent.com/28162685/28127972-2ecf0362-66fc-11e7-9737-cf209289182f.png)

# %% [markdown]
# Continuing with square feet as one-dimension (to give a sense of where our last data points fell), look at what differentiated the outliers with normal square footage. A few schools with very high enrollment (1500+) were labeled as outliers.

# %%
display(schools_df)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#             IForest: Enrollment vs. Square Feet
#         </div>
#     <div id="chartFiguref540128d" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-f540128d")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"da295944-0490-4ccb-9c63-1bc8a5cf7976":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"fa27ec07-7666-47ae-9eaa-d555c6f765bf","type":"Circle"},{"attributes":{},"id":"709f0c53-dab6-450d-9ed0-a78157e52936","type":"BasicTicker"},{"attributes":{},"id":"f6941275-47df-4001-9671-fa0ead2ac120","type":"WheelZoomTool"},{"attributes":{},"id":"38d9b7ce-8ada-4e9f-a6eb-6a496e99c768","type":"HelpTool"},{"attributes":{},"id":"6cf6aa47-0ec0-4f98-82db-45088836b7a0","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"3487de87-44d7-4b79-9e71-2f80e7626c72","type":"LinearAxis"}],"left":[{"id":"ef0af71b-b601-45e1-be76-8c98cfb4b3d6","type":"LinearAxis"}],"plot_height":490,"plot_width":985,"renderers":[{"id":"3487de87-44d7-4b79-9e71-2f80e7626c72","type":"LinearAxis"},{"id":"c374f10f-2e83-4185-a2d8-6a908f4907c4","type":"Grid"},{"id":"ef0af71b-b601-45e1-be76-8c98cfb4b3d6","type":"LinearAxis"},{"id":"55d7c6e9-08ef-4b85-8104-675d2d1a9bdf","type":"Grid"},{"id":"4e298c31-4f9e-4c91-acb1-8ca7c6a8f840","type":"BoxAnnotation"},{"id":"a1cbe40b-64f0-4a15-8cc9-ef713da1b8af","type":"GlyphRenderer"}],"title":{"id":"7523ae6e-9fb8-45fa-8608-4239fee90d12","type":"Title"},"toolbar":{"id":"1fad4160-1ab6-47d2-9a1f-90470b5b772f","type":"Toolbar"},"x_range":{"id":"b5c3c4df-5b4f-4dd8-b487-19c6db358623","type":"DataRange1d"},"x_scale":{"id":"a2d3d11e-73de-4c8a-904f-bef9b7b48365","type":"LinearScale"},"y_range":{"id":"c75dc2f1-f013-4f2b-8ec5-8b5b0e9dbd73","type":"DataRange1d"},"y_scale":{"id":"8b307e6a-a307-4c7f-9400-1859f534aaa9","type":"LinearScale"}},"id":"e26ea892-4251-431f-a5ca-31c782e7f719","subtype":"Figure","type":"Plot"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"38f3dfaf-4f81-461f-96ef-844f784540af","type":"Circle"},{"attributes":{"callback":null},"id":"c75dc2f1-f013-4f2b-8ec5-8b5b0e9dbd73","type":"DataRange1d"},{"attributes":{},"id":"57f73bd5-0efe-4e92-af4d-70701247bc2d","type":"PanTool"},{"attributes":{"dimension":1,"grid_line_alpha":{"value":0.3},"plot":{"id":"e26ea892-4251-431f-a5ca-31c782e7f719","subtype":"Figure","type":"Plot"},"ticker":{"id":"41fe6cc7-3686-45eb-bfb1-3ae226129fa0","type":"BasicTicker"}},"id":"55d7c6e9-08ef-4b85-8104-675d2d1a9bdf","type":"Grid"},{"attributes":{"axis_label":"DOE_Total","formatter":{"id":"99df65f0-3a8e-44c6-b892-6211fc38bd33","type":"BasicTickFormatter"},"plot":{"id":"e26ea892-4251-431f-a5ca-31c782e7f719","subtype":"Figure","type":"Plot"},"ticker":{"id":"709f0c53-dab6-450d-9ed0-a78157e52936","type":"BasicTicker"}},"id":"3487de87-44d7-4b79-9e71-2f80e7626c72","type":"LinearAxis"},{"attributes":{},"id":"99df65f0-3a8e-44c6-b892-6211fc38bd33","type":"BasicTickFormatter"},{"attributes":{},"id":"8b307e6a-a307-4c7f-9400-1859f534aaa9","type":"LinearScale"},{"attributes":{"overlay":{"id":"4e298c31-4f9e-4c91-acb1-8ca7c6a8f840","type":"BoxAnnotation"}},"id":"60e3f0b6-6400-41f8-954a-6ea171676d08","type":"BoxZoomTool"},{"attributes":{},"id":"900a6b67-e777-4ed5-b71f-8cc2a5435253","type":"ResetTool"},{"attributes":{"axis_label":"SMMA_Site_SF","formatter":{"id":"6cf6aa47-0ec0-4f98-82db-45088836b7a0","type":"BasicTickFormatter"},"plot":{"id":"e26ea892-4251-431f-a5ca-31c782e7f719","subtype":"Figure","type":"Plot"},"ticker":{"id":"41fe6cc7-3686-45eb-bfb1-3ae226129fa0","type":"BasicTicker"}},"id":"ef0af71b-b601-45e1-be76-8c98cfb4b3d6","type":"LinearAxis"},{"attributes":{},"id":"a2d3d11e-73de-4c8a-904f-bef9b7b48365","type":"LinearScale"},{"attributes":{},"id":"1db6f017-e9db-42d1-9252-50ad73d5b465","type":"SaveTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"57f73bd5-0efe-4e92-af4d-70701247bc2d","type":"PanTool"},{" ...

# %% [markdown]
# ![iforest_enrollment_sqft](https://user-images.githubusercontent.com/28162685/28128007-43e35924-66fc-11e7-98a6-f8e849802b33.png)

# %% [markdown]
# Finally (and most helpfully), look at *Principal Earnings* against *Square feet*. Several principals have very low earnings. This may be because they joined the district at the beginning of the school year and only earned about half of a full year's salary. These data points would need to be removed or adjusted going forward.

# %%
display(schools_df)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#             IForest: Principal Earnings vs. Square Feet
#         </div>
#     <div id="chartFigure7f9862cd" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-7f9862cd")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"a79573bb-8bce-41c9-8566-9cc213d30fa7":{"roots":{"references":[{"attributes":{"plot":null,"text":"IForest: Principal Earnings vs. Square Feet"},"id":"cf9cb907-6567-4831-b5b3-001567c2533d","type":"Title"},{"attributes":{"callback":null},"id":"2fb7e512-8b2f-4230-adb5-334a83c1daa6","type":"DataRange1d"},{"attributes":{},"id":"b3502359-7c53-4905-b8e7-54041cb176af","type":"PanTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"6909d1ed-6713-41b6-9356-865025e69037","type":"Circle"},{"attributes":{},"id":"84fc5a7f-d802-48a6-a1c6-87b9e3e03d64","type":"ResetTool"},{"attributes":{"source":{"id":"f1d839ab-8adb-4c77-b365-e5a74739ed84","type":"ColumnDataSource"}},"id":"9ae9bc76-ae48-4c85-96c0-3257bcb85bc2","type":"CDSView"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"04ed716f-6521-40cf-bb06-b30f99668415","type":"Circle"},{"attributes":{"overlay":{"id":"37092a24-f37b-4e88-be14-4c702514b6d7","type":"BoxAnnotation"}},"id":"f88c2e58-a4e1-48c8-937d-5cd93e1f8cf0","type":"BoxZoomTool"},{"attributes":{"grid_line_alpha":{"value":0.3},"plot":{"id":"40d15c86-04c0-4095-9879-c55bd7b15751","subtype":"Figure","type":"Plot"},"ticker":{"id":"e41458de-4817-4c02-b73a-3755203ce8c6","type":"BasicTicker"}},"id":"8f3d378c-3eeb-4ea6-be2c-d85f39e3770b","type":"Grid"},{"attributes":{"axis_label":"SMMA_Site_SF","formatter":{"id":"e5dae312-8518-479d-a301-664c6103160b","type":"BasicTickFormatter"},"plot":{"id":"40d15c86-04c0-4095-9879-c55bd7b15751","subtype":"Figure","type":"Plot"},"ticker":{"id":"8e5a4ea7-219b-4755-bd1e-a8287909420d","type":"BasicTicker"}},"id":"6df446a4-6282-47fd-b201-6ea60da32a85","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[56649.97,57796.5,69625.01,74056.27,74446.77,82800.32,85272.0,85382.48,92541.68,93572.42,110829.89,111214.86,113222.99,113222.99,113347.57,115718.89,116253.14,116343.93,116851.94,116977.5,117017.05,117017.05,117318.96,117475.61,120017.05,121503.83,121940.77,122193.93,122193.93,123460.0,123540.84,123698.49,123811.08,124015.59,124079.16,124853.98,124870.42,125479.16,125856.09,125903.13,126069.31,126532.68,126629.97,126680.86,127276.08,127345.53,127403.13,127683.78,127896.56,128083.92,128215.54,129071.92,129170.76,129688.4,130070.2,130586.91,130891.44,130931.6,131165.29,131303.27,131487.47,131694.43,133266.65,133546.72,134377.51,134973.54,135338.96,135375.16,135497.36,135919.81,136157.93,136848.62,137000.37,137000.37,137792.27,138036.07,138140.02,139282.12,139490.02,139582.42,140528.44,140841.26,140962.32,141082.42,141156.36,141862.5,142454.52,144135.7,144815.86,147135.72,154619.0,156826.9,160182.78],"y":[57329.0,115536.0,73586.0,148351.0,211748.0,117847.0,282110.0,290048.0,610119.0,117393.0,8736.0,72143.0,29990.0,48573.0,37850.0,40680.0,44999.0,43382.0,237737.0,34336.0,29932.0,35445.0,56384.0,60408.0,69377.0,194261.0,144255.0,52800.0,47958.0,24723.0,167794.0,82860.0,38670.0,181714.0,49940.0,58845.0,73819.0,102660.0,69281.0,54952.0,152690.0,67138.0,117847.0,85562.0,64004.0,56006.0,79305.0,181714.0,47521.0,26000.0,247082.0,117848.0,33042.0,52065.0,35491.0,39227.0,83088.0,175916.0,101387.0,66327.0,157411.0,1938398.0,301553.0,66918.0,19853.0,69502.0,78914.0,247082.0,58974.0,5328.0,220875.0,124571.0,38670.0,84410.0,159439.0,141611.0,83598.0,159439.0,45821.0,58932.0,78697.0,128117.0,438649.0,40000.0,58932.0,174997.0,67077.0,78697.0,69049.0,119598.0,403445.0,260579.0,145153.0]}},"id":"f1d839ab-8adb-4c77-b365-e5a74739ed84","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"6b8d7072-fa81-4827-b300-322f0a0f17f0","type":"DataRange1d"},{"attributes":{},"id":"683ea5d3-839e-4e04-936b-ead09c600869","type":"WheelZoomTool"},{"attributes":{},"id":"50ed4424- ...

# %% [markdown]
# ![iforest_earnings_sqft](https://user-images.githubusercontent.com/28162685/28127541-e90b4710-66fa-11e7-8bc3-edb43cca037a.png)

# %% [markdown]
# ### One Class SVM
#
# One Class SVM looks to be a poorer fit (or less well-tuned) for this data set. The graphs below show the outliers show no clear pattern.

# %%
display(schools_df)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#             SVM: Energy Cost vs Square Feet
#         </div>
#     <div id="chartFiguree6f84ca0" class="pd_save is-viewer-good" style="overflow-x:auto">
#
#                     <script class="pd_save">
#                     function setChartScript() {
#                         if (!window.Bokeh) {
#                             setTimeout(setChartScript, 250)
#                         } else {
#                             var d = document.getElementById("pd-bkchartdiv-e6f84ca0")
#                             if (d){
#                                 var el = document.createElement('div')
#                                 el.innerHTML = `
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
#           var docs_json = '{"8a3a6cab-fe24-46e9-bc50-d0aaca575889":{"roots":{"references":[{"attributes":{},"id":"62958f01-bc12-4f66-9858-2f8c3a9db240","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"d1215ad4-d67e-426c-ae8d-dd8fa2b1ffc9","type":"BoxAnnotation"}},"id":"ea2fa8f0-81d9-4d6f-9c8f-aaf525433191","type":"BoxZoomTool"},{"attributes":{},"id":"76ac7dcb-9f29-434f-851a-cc436e010dd3","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"dd471d62-4c22-4b2a-8579-9776a6319bee","type":"ColumnDataSource"},"glyph":{"id":"a0e81fd8-53f1-490c-b11b-389421c246c8","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1c5a6789-74a3-432c-94b7-abd8ee196e7c","type":"Circle"},"selection_glyph":null,"view":{"id":"2461663a-d0e3-4028-af6b-529d2e80c710","type":"CDSView"}},"id":"1b0f7888-275c-4af9-97a6-f177a54063bd","type":"GlyphRenderer"},{"attributes":{"axis_label":" BPS_Total_Energy_Cost ","formatter":{"id":"62958f01-bc12-4f66-9858-2f8c3a9db240","type":"BasicTickFormatter"},"plot":{"id":"093ac454-ff5d-4f8f-a95a-0609fe495c7e","subtype":"Figure","type":"Plot"},"ticker":{"id":"fe48dbad-0eba-4a19-bfef-d754cbf867b7","type":"BasicTicker"}},"id":"05dc39d4-1346-4797-8e48-3d77a1ed1588","type":"LinearAxis"},{"attributes":{},"id":"f7cc669f-0a70-4a14-97ce-b024d968fddc","type":"BasicTickFormatter"},{"attributes":{"axis_label":"SMMA_Site_SF","formatter":{"id":"f7cc669f-0a70-4a14-97ce-b024d968fddc","type":"BasicTickFormatter"},"plot":{"id":"093ac454-ff5d-4f8f-a95a-0609fe495c7e","subtype":"Figure","type":"Plot"},"ticker":{"id":"0c73c9b0-025d-4830-99ec-8fc182f57eb7","type":"BasicTicker"}},"id":"982bd937-ebbf-4c83-b01e-a8b4dca58a86","type":"LinearAxis"},{"attributes":{},"id":"a9a082b3-9d71-4dd3-899c-96eabe7b4e4d","type":"LinearScale"},{"attributes":{"dimension":1,"grid_line_alpha":{"value":0.3},"plot":{"id":"093ac454-ff5d-4f8f-a95a-0609fe495c7e","subtype":"Figure","type":"Plot"},"ticker":{"id":"0c73c9b0-025d-4830-99ec-8fc182f57eb7","type":"BasicTicker"}},"id":"f554a23d-7212-48f7-872d-90f1be0d487c","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"a0e81fd8-53f1-490c-b11b-389421c246c8","type":"Circle"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"d1215ad4-d67e-426c-ae8d-dd8fa2b1ffc9","type":"BoxAnnotation"},{"attributes":{},"id":"0c95b1fc-b764-419e-be1b-e7e07fab402f","type":"HelpTool"},{"attributes":{"callback":null},"id":"394d2e3a-ea3a-44b0-b03f-5838e638a594","type":"DataRange1d"},{"attributes":{"callback":null},"id":"6d5b8304-aa87-4531-93f7-f8fc4b0e079c","type":"DataRange1d"},{"attributes":{"below":[{"id":"05dc39d4-1346-4797-8e48-3d77a1ed1588","type":"LinearAxis"}],"left":[{"id":"982bd937-ebbf-4c83-b01e-a8b4dca58a86","type":"LinearAxis"}],"plot_height":490,"plot_width":985,"renderers":[{"id":"05dc39d4-1346-4797-8e48-3d77a1ed1588","type":"LinearAxis"},{"id":"7d5d3639-d088-4ef6-b5bf-5f717cadf1cf","type":"Grid"},{"id":"982bd937-ebbf-4c83-b01e-a8b4dca58a86","type":"LinearAxis"},{"id":"f554a23d-7212-48f7-872d-90f1be0d487c","type":"Grid"},{"id":"d1215ad4-d67e-426c-ae8d-dd8fa2b1ffc9","type":"BoxAnnotation"},{"id":"1b0f7888-275c-4af9-97a6-f177a54063bd","type":"GlyphRenderer"}],"title":{"id":"b83c1f8f-5222-4b70-ac15-59117975374c","type":"Title"},"toolbar":{"id":"c93598c4-f0c0-4258-a4a5-1cd478a460ff","type":"Toolbar"},"x_range":{"id":"394d2e3a-ea3a-44b0-b03f-5838e638a594","type":"DataRange1d"},"x_scale":{"id":"a9a082b3-9d71-4dd3-899c-96eabe7b4e4d","type":"LinearScale"},"y_range":{"id":"6d5b8304-aa87-4531-93f7-f8fc4b0e079c","type":"DataRange1d"},"y_scale":{"id":"0d8d2fab-33f0-495f-9bc5-7487da898dce", ...

# %% [markdown]
# ![svm_energycost_sqft](https://user-images.githubusercontent.com/28162685/28128108-a5fe2062-66fc-11e7-88eb-0515efc0a81e.png)
# ![svm_enrollment_sqft](https://user-images.githubusercontent.com/28162685/28128125-b4034fa2-66fc-11e7-8cbf-955d1085c820.png)
# ![svm_earnings_sqft](https://user-images.githubusercontent.com/28162685/28128087-8e358290-66fc-11e7-9b7f-e047bfdbbb7f.png)

# %% [markdown]
# ## 6. Next steps<a class="anchor" id="nextsteps"></a>
# Next, you could add more functionality for users in the outlier PixieApp, including some tuning options, more algorithms, and PixieDust Events to link the plots to the dataframe.
# You could also look at adjusting for the outliers and trying out algorithms to answer the questions laid out at the beginning of this notebook.

# %% [markdown]
# ### Author
#
# **Tanya Rudakeyvch** is a data scientist at IBM USA.

# %% [markdown]
# Copyright © IBM Corp. 2017, 2018. This notebook and its source code are released under the terms of the MIT License.
