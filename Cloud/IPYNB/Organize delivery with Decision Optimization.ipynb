# %% [markdown]
# # The Truck Fleet puzzle - Organize product delivery with Decision Optimization
#
# This tutorial includes everything you need to set up Decision Optimization engines, build constraint programming models.
#
# **Table of contents:**
#
# -  [Describe the business problem](#Describe-the-business-problem)
# *  [How Decision Optimization can help](#How-Decision-Optimization-can-help)
# *  [Use Decision Optimization](#Use-Decision-Optimization)
#     *  [Step 1: Model the Data](#Step-1:-Model-the-data)
#     *  [Step 2: Set up the prescriptive model](#Step-2:-Set-up-the-prescriptive-model)
#         * [Prepare data for modeling](#Prepare-data-for-modeling)
#         * [Define the decision variables](#Define-the-decision-variables)
#         * [Express the business constraints](#Express-the-business-constraints)
#         * [Express the objective](#Express-the-objective)
#         * [Solve with Decision Optimization solve service](#Solve-with-Decision-Optimization-solve-service)
#     *  [Step 3: Investigate the solution and run an example analysis](#Step-3:-Investigate-the-solution-and-then-run-an-example-analysis)
# *  [Summary](#Summary)
# ****

# %% [markdown]
# ### Describe the business problem
#
# * The problem is to deliver some orders to several clients with a single truck.
# * Each order consists of a given quantity of a product of a certain type.
# * A product type is an integer in {0, 1, 2}.
# * Loading the truck with at least one product of a given type requires some specific installations.
# * The truck can be configured in order to handle one, two or three different types of product.
# * There are 7 different configurations for the truck, corresponding to the 7 possible combinations of product types:
#  - configuration 0: all products are of type 0,
#  - configuration 1: all products are of type 1,
#  - configuration 2: all products are of type 2,
#  - configuration 3: products are of type 0 or 1,
#  - configuration 4: products are of type 0 or 2,
#  - configuration 5: products are of type 1 or 2,
#  - configuration 6: products are of type 0 or 1 or 2.
# * The cost for configuring the truck from a configuration A to a configuration B depends on A and B.
# * The configuration of the truck determines its capacity and its loading cost.
# * A delivery consists of loading the truck with one or several orders for the same customer.
# * Both the cost (for configuring and loading the truck) and the number of deliveries needed to deliver all the orders must be minimized, the cost being the most important criterion.
#
# Please refer to documentation for appropriate setup of solving configuration.

# %% [markdown]
# *****
# ## How Decision Optimization can help
# * Prescriptive analytics (Decision Optimization) technology recommends actions based on desired outcomes, taking into account specific scenarios, resources, and knowledge of past and current events. This insight can help your organization make better decisions and have greater control of business outcomes.
#
# * Prescriptive analytics is the next step on the path to insight-based actions. It creates value through synergy with predictive analytics, which analyzes data to predict future outcomes.
#
# * Prescriptive analytics takes that insight to the next level by suggesting the optimal way to handle that future situation. Organizations that can act fast in dynamic conditions and make superior decisions in uncertain environments gain a strong competitive advantage.
# <br/>
#
# + For example:
#     + Automate complex decisions and trade-offs to better manage limited resources.
#     + Take advantage of a future opportunity or mitigate a future risk.
#     + Proactively update recommendations based on changing events.
#     + Meet operational goals, increase customer loyalty, prevent threats and fraud, and optimize business processes.

# %% [markdown]
# ## Use Decision Optimization

# %% [markdown]
# ### Step 1: Model the data

# %% [markdown]
# Use the Constraint Programming modeling package and define the data for the problem.

# %%
from docplex.cp.model import *

# %%
# List of possible truck configurations. Each tuple is (load, cost) with:
#    load: max truck load for this configuration,
#    cost: cost for loading the truck in this configuration
TRUCK_CONFIGURATIONS = ((11, 2), (11, 2), (11, 2), (11, 3), (10, 3), (10, 3), (10, 4))

# List of customer orders.
# Each tuple is (customer index, volume, product type)
CUSTOMER_ORDERS = ((0, 3, 1), (0, 4, 2), (0, 3, 0), (0, 2, 1), (0, 5, 1), (0, 4, 1), (0, 11, 0),
                   (1, 4, 0), (1, 5, 0), (1, 2, 0), (1, 4, 2), (1, 7, 2), (1, 3, 2), (1, 5, 0), (1, 2, 2),
                   (2, 5, 1), (2, 6, 0), (2, 11, 2), (2, 1, 0), (2, 6, 0), (2, 3, 0))

# Transition costs between configurations.
# Tuple (A, B, TCost) means that the cost of  modifying the truck from configuration A to configuration B is TCost
CONFIGURATION_TRANSITION_COST = tuple_set(((0, 0,  0), (0, 1,  0), (0, 2,  0), (0, 3, 10), (0, 4, 10),
                                           (0, 5, 10), (0, 6, 15), (1, 0,  0), (1, 1,  0), (1, 2,  0),
                                           (1, 3, 10), (1, 4, 10), (1, 5, 10), (1, 6, 15), (2, 0,  0),
                                           (2, 1,  0), (2, 2,  0), (2, 3, 10), (2, 4, 10), (2, 5, 10),
                                           (2, 6, 15), (3, 0,  3), (3, 1,  3), (3, 2,  3), (3, 3,  0),
                                           (3, 4, 10), (3, 5, 10), (3, 6, 15), (4, 0,  3), (4, 1,  3),
                                           (4, 2,  3), (4, 3, 10), (4, 4,  0), (4, 5, 10), (4, 6, 15),
                                           (5, 0,  3), (5, 1,  3), (5, 2,  3), (5, 3, 10), (5, 4, 10),
                                           (5, 5,  0), (5, 6, 15), (6, 0,  3), (6, 1,  3), (6, 2,  3),
                                           (6, 3, 10), (6, 4, 10), (6, 5, 10), (6, 6,  0)))

# Compatibility between the product types and the configuration of the truck
# allowedContainerConfigs[i] = the array of all the configurations that accept products of type i
ALLOWED_CONTAINER_CONFIGS = ((0, 3, 4, 6),
                             (1, 3, 5, 6),
                             (2, 4, 5, 6))

# %% [markdown]
# ### Step 2: Set up the prescriptive model

# %% [markdown]
# #### Prepare data for modeling

# %% [markdown]
# The next section extracts from problem data the parts that are frequently used in the modeling section.

# %%
nbTruckConfigs = len(TRUCK_CONFIGURATIONS)
maxTruckConfigLoad = [tc[0] for tc in TRUCK_CONFIGURATIONS]
truckCost = [tc[1] for tc in TRUCK_CONFIGURATIONS]
maxLoad = max(maxTruckConfigLoad)

nbOrders = len(CUSTOMER_ORDERS)
nbCustomers = 1 + max(co[0] for co in CUSTOMER_ORDERS)
volumes = [co[1] for co in CUSTOMER_ORDERS]
productType = [co[2] for co in CUSTOMER_ORDERS]

# Max number of truck deliveries (estimated upper bound, to be increased if no solution)
maxDeliveries = 15

# %% [markdown]
# #### Create CPO model

# %%
mdl = CpoModel(name="trucks")

# %% [markdown]
# #### Define the decision variables

# %%
# Configuration of the truck for each delivery
truckConfigs = integer_var_list(maxDeliveries, 0, nbTruckConfigs - 1, "truckConfigs")
# In which delivery is an order
where = integer_var_list(nbOrders, 0, maxDeliveries - 1, "where")
# Load of a truck
load = integer_var_list(maxDeliveries, 0, maxLoad, "load")
# Number of deliveries that are required
nbDeliveries = integer_var(0, maxDeliveries)
# Identification of which customer is assigned to a delivery
customerOfDelivery = integer_var_list(maxDeliveries, 0, nbCustomers, "customerOfTruck")
# Transition cost for each delivery
transitionCost = integer_var_list(maxDeliveries - 1, 0, 1000, "transitionCost")

# %% [markdown]
# #### Express the business constraints

# %%
# transitionCost[i] = transition cost between configurations i and i+1
for i in range(1, maxDeliveries):
    auxVars = (truckConfigs[i - 1], truckConfigs[i], transitionCost[i - 1])
    mdl.add(allowed_assignments(auxVars, CONFIGURATION_TRANSITION_COST))

# Constrain the volume of the orders in each truck
mdl.add(pack(load, where, volumes, nbDeliveries))
for i in range(0, maxDeliveries):
    mdl.add(load[i] <= element(truckConfigs[i], maxTruckConfigLoad))

# Compatibility between the product type of an order and the configuration of its truck
for j in range(0, nbOrders):
    configOfContainer = integer_var(ALLOWED_CONTAINER_CONFIGS[productType[j]])
    mdl.add(configOfContainer == element(truckConfigs, where[j]))

# Only one customer per delivery
for j in range(0, nbOrders):
    mdl.add(element(customerOfDelivery, where[j]) == CUSTOMER_ORDERS[j][0])

# Non-used deliveries are at the end
for j in range(1, maxDeliveries):
    mdl.add((load[j - 1] > 0) | (load[j] == 0))

# Dominance: the non used deliveries keep the last used configuration
mdl.add(load[0] > 0)
for i in range(1, maxDeliveries):
    mdl.add((load[i] > 0) | (truckConfigs[i] == truckConfigs[i - 1]))

# Dominance: regroup deliveries with same configuration
for i in range(maxDeliveries - 2, 0, -1):
    ct = true()
    for p in range(i + 1, maxDeliveries):
        ct = (truckConfigs[p] != truckConfigs[i - 1]) & ct
    mdl.add((truckConfigs[i] == truckConfigs[i - 1]) | ct)

# %% [markdown]
# #### Express the objective

# %%
# Objective: first criterion for minimizing the cost for configuring and loading trucks 
#            second criterion for minimizing the number of deliveries
cost = sum(transitionCost) + sum(element(truckConfigs[i], truckCost) * (load[i] != 0) for i in range(maxDeliveries))
mdl.add(minimize_static_lex([cost, nbDeliveries]))

# %% [markdown]
# #### Solve with Decision Optimization solve service

# %%
# Search strategy: first assign order to truck
mdl.set_search_phases([search_phase(where)])

# Solve model
print("\nSolving model....")
msol = mdl.solve(TimeLimit=20)
# Out:
# Solving model....
#  ! --------------------------------------------------- CP Optimizer 22.1.0.0 --
#  ! Minimization problem - 102 variables, 114 constraints, 1 phase
#  ! TimeLimit            = 20
#  ! Initial process time : 0.00s (0.00s extraction + 0.00s propagation)
#  !  . Log search space  : 280.6 (before), 280.6 (after)
#  !  . Memory usage      : 509.6 kB (before), 509.6 kB (after)
#  ! Using parallel search with 32 workers.
#  ! ----------------------------------------------------------------------------
#  !          Best Branches  Non-fixed    W       Branch decision
#                         0        102                 -
#  + New bound is 2; 9
#                         0        102    1   F        -
#  + New bound is 4; -9007199254740990
#                         0        102    1   F        -
#  + New bound is 4; -9007199254740989
#  *            40       41  0.82s        1      (gap is 90.00% @ crit. 1 of 2)
#    New objective is 40; 11
#               40     1000          1    1        11 != where_3
#               40     1000          1    2         0  = transitionCost_13
#               40     1000          1    3         4 != where_9
#               40     1000          1    4         5  = where_2
#               40     1000          1    5         4 != _INT_16
#               40     1000          1    6         4 != _INT_21
#               40     1000          1    7         8  = where_1
#               40     1000          1    8        11 != where_12
#               40     1000          1    9         6 != _INT_9
#               40     1000          1   10         9 != where_10
#               40     1000          1   11         6  = truckConfigs_14
#               40     1000          4   12         7 != where_11
#               40     1000          1   13   F     2  = _INT_13
#               40     1000         12   14            -
#               40     1000          4   15        12  = where_10
#               40     1000         53   16         7 != where_8
#  ! Time = 0.82s, Average fail depth = 20, Memory usage = 17.3 MB
#  ! Current objective is 40; 11
#  ! Current bound is 4; -9007199254740989 (gap is 90.00% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               40     1000          1   17   F     6 != where_8
#               40     1000          1   18   F    12  = where_15
#               40     1000          1   19        10 != transitionCost_3
#               40     1000          1   20   F     0 != transitionCost_1
#               40     1000          1   21         5  = _INT_2
#               40     1000          3   22   F     6  = _INT_2
#               40     1000          1   23         5 != where_14
#               40     1000          4   24         4  = _INT_13
#               40     1000          1   25   F     9  = where_16
#               40     1000          1   26         1  = where_9
#               40     1000          1   27         0  = customerOfTruck_11
#               40     1000          1   28   F    10  = transitionCost_1
#               40     1000          1   29   F     5  = truckConfigs_5
#               40     1000          1   30   F    10 != transitionCost_1
#               40     1000          1   31   F     1  = _INT_2
#               40     1000          1   32   F     4 != truckConfigs_8
#               40     2000          1    1   F    10  = where_15
#               40     2000          7    7   F    10 != where_5
#               40     2000         17   12         0  = where_12
#               40     2000         10   22         0  = transitionCost_1
#  ! Time = 1.32s, Average fail depth = 25, Memory usage = 32.8 MB
#  ! Current objective is 40; 11
#  ! Current bound is 4; -9007199254740989 (gap is 90.00% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               40     2000          1    2        10 != where_18
#  *            37     1128  1.32s        3      (gap is 89.19% @ crit. 1 of 2)
#    New objective is 37; 15
#  *            34     1525  1.32s        3      (gap is 88.24% @ crit. 1 of 2)
#    New objective is 34; 15
#               34     2000          8    6   F     9  = where_16
#               34     2000          1    9   F    12  = where_2
#               34     2000          1   15        11 != where_13
#  *            30     1066  1.32s       20      (gap is 86.67% @ crit. 1 of 2)
#    New objective is 30; 15
#               30     2000         15   21   F     6 != where_8
#               30     2000          1   31   F     3  = transitionCost_1
#               30     2000          3    3         0  = transitionCost_0
#               30     2000          1    4   F     8  = where_10
#               30     2000         21    5   F     6  = where_1
#               30     2000         25    8         6  = where_12
#               30     2000         43   10         4  = where_0
#               30     2000          3   11   F    11  = where_9
#               30     2000          1   13        15 != transitionCost_2
#               30     2000         14   14         0 != where_0
#               30     2000         38   16   F     2  = truckConfigs_6
#               30     2000          3   17         3 != where_7
#               30     2000         13   18         0  = transitionCost_3
#  ! Time = 1.79s, Average fail depth = 27, Memory usage = 33.2 MB
#  ! Current objective is 30; 15
#  ! Current bound is 4; -9007199254740989 (gap is 86.67% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               30     2000         16   19   F    10  = where_4
#               30     2000          6   20   F     0 != where_17
#               30     2000          1   23   F     5  = where_4
#               30     2000          4   24   F     8  = where_1
#               30     2000          1   25         1 != where_10
#               30     2000         26   26   F     2  = where_15
#               30     2000          4   27         0  = where_15
#               30     2000         35   28         5 != where_6
#               30     2000          1   29   F     5  = truckConfigs_9
#               30     2000         24   30   F     6  = truckConfigs_6
#               30     2000          3   32        13  = where_18
#               30     3000         23    2   F     9 != where_17
#  *            26     2215  1.82s        3      (gap is 84.62% @ crit. 1 of 2)
#    New objective is 26; 13
#               26     3000          1    7         2 != truckConfigs_12
#               26     3000         36   32         4 != where_18
#               26     3000         47    1   F    13  = where_4
#               26     3000          1    3   F     6  = where_6
#               26     3000          1    4   F     6  = where_2
#               26     3000         24    5   F     7  = where_2
#               26     3000         24    6         2  = where_17
#  ! Time = 2.27s, Average fail depth = 27, Memory usage = 33.4 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26     3000         36    8        10 != where_19
#               26     3000          1    9   F     0  = _INT_20
#               26     3000          8   10         2  = where_16
#               26     3000         21   11   F     8  = where_1
#               26     3000         28   12   F    13  = where_18
#               26     3000         29   14   F    13 != where_1
#               26     3000         29   15   F     9 != where_1
#               26     3000         29   16   F    14  = where_0
#               26     3000         20   17        14 != where_20
#               26     3000          1   19        10 != where_1
#               26     3000         32   20         4 != where_2
#               26     3000         13   21         9 != where_13
#               26     3000         32   22         7 != where_19
#               26     3000          9   23   F     0  = _INT_21
#               26     3000         15   24         8  = where_18
#               26     3000         27   25   F    13 != where_4
#               26     3000         19   26        12 != where_17
#               26     3000         14   27   F     0 != transitionCost_8
#               26     3000         44   28   F    12  = where_9
#               26     3000         12   29   F     5  = where_9
#  ! Time = 2.29s, Average fail depth = 27, Memory usage = 33.4 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26     3000         29   30         7 != where_7
#               26     3000         18   13         5 != where_16
#               26     3000          1   31         0  = where_12
#               26     4000         45   32   F     6  = where_14
#               26     4000         21    1         6 != where_7
#               26     4000         44    3   F    13 != where_12
#               26     4000         41    4        14 != where_8
#               26     4000         43    5        12 != where_17
#               26     4000         24    6   F     5  = where_13
#               26     4000         15    7   F     6 != _INT_4
#               26     4000         74    8   F     7  = where_6
#               26     4000         25    9         0 != truckConfigs_1
#               26     4000         33   10        13 != where_2
#               26     4000         28   11   F     6  = _INT_15
#               26     4000         28   12   F     2  = where_17
#               26     4000         26   13         0  = where_10
#               26     4000         37   14         0 != where_3
#               26     4000          1   15         4 != where_1
#               26     4000         14   17         3  = where_14
#               26     3000         30   18   F    10  = where_20
#  ! Time = 2.86s, Average fail depth = 27, Memory usage = 33.5 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26     4000         52   19        11 != where_2
#               26     4000         57   20         9 != where_1
#               26     4000         23   21         7 != where_19
#               26     4000         37   22   F    12  = where_17
#               26     4000         39   24   F    13 != where_0
#               26     4000         37   25   F     3  = truckConfigs_8
#               26     4000         41   26         6 != where_3
#               26     4000         16   27   F     3 != transitionCost_4
#               26     4000         26   29   F     2 != _INT_16
#               26     4000         33   30        14 != where_6
#               26     4000         25   31   F     6  = _INT_22
#               26     4000         47    2   F    12  = where_12
#               26     4000          9   23        13 != where_12
#               26     5000         32   25         4 != where_20
#               26     5000         18   27   F    14  = where_19
#               26     4000         59   28   F    12  = where_19
#               26     5000         22   29        13 != where_19
#               26     5000         21    1        11 != where_12
#               26     5000         27    5   F    13  = where_13
#               26     5000         24    6         2 != where_10
#  ! Time = 3.34s, Average fail depth = 27, Memory usage = 33.6 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26     5000         18    7         5  = _INT_2
#               26     5000         52    8         1 != where_16
#               26     5000         20    9   F     8  = where_17
#               26     5000         22   10         3 != where_19
#               26     5000         15   11         6 != where_12
#               26     5000          8   13         2 != where_14
#               26     5000         23   14         8 != where_8
#               26     4000         44   16   F     3  = where_0
#               26     5000         24   17         3 != transitionCost_0
#               26     4000         35   18         8 != where_15
#               26     5000         48   19         7 != where_15
#               26     5000         23   20         2 != where_19
#               26     5000         37   21   F    11 != where_4
#               26     5000         37   22   F     8  = where_19
#               26     5000          1   31   F     3  = where_5
#               26     5000         31    4         9  = where_7
#               26     5000         26   15         9  = where_13
#               26     5000         24   23         6  = where_15
#               26     5000         33   24        12 != where_11
#               26     6000         21   25   F     3  = truckConfigs_13
#  ! Time = 3.86s, Average fail depth = 27, Memory usage = 33.8 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26     5000         23   26   F    12  = where_8
#               26     6000         31   27   F    12  = where_17
#               26     5000         44   28   F    12  = where_10
#               26     6000         25   29         6  = where_18
#               26     5000         44   30   F     1  = where_8
#               26     6000         39   31   F     4  = _INT_9
#               26     5000         45   32   F    12  = where_15
#               26     6000         11    1         6 != where_6
#               26     5000         33    2        12 != where_5
#               26     5000         43    3   F    10  = where_8
#               26     6000         26    6        12 != where_17
#               26     6000          1    7   F     0  = transitionCost_2
#               26     6000         52    8   F    10  = where_2
#               26     6000         25    9         2  = where_9
#               26     6000         22   10         4  = where_11
#               26     5000         36   12         4 != where_20
#               26     6000         21   13         4  = where_8
#               26     6000         12   15   F     0 != transitionCost_4
#               26     5000         38   16   F    13  = where_3
#               26     6000         22   17        10 != where_7
#  ! Time = 3.86s, Average fail depth = 27, Memory usage = 33.8 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26     5000         41   18   F     6  = where_17
#               26     6000         41   19   F     9  = where_11
#               26     6000         22   21   F     0 != _INT_8
#               26     6000         28   22   F     5  = where_3
#               26     6000         10    4        12 != where_9
#               26     7000         14   10        13 != where_2
#               26     6000         44   11        11 != where_8
#               26     6000         20   12         5 != where_15
#               26     7000         32   13   F     8  = where_7
#               26     6000         23   14         7 != where_11
#               26     7000         15   15   F    11  = where_8
#               26     7000         35   17   F    11 != where_0
#               26     6000         22   18   F     5  = where_2
#               26     7000         48   19   F     6  = where_2
#               26     6000         31   20         8 != where_2
#               26     7000         24   21         5  = where_10
#               26     7000         16   22   F    14 != where_12
#               26     6000         30   23        10 != where_18
#               26     6000         32   24   F    11  = where_4
#               26     7000         22   25   F    10  = where_20
#  ! Time = 4.42s, Average fail depth = 27, Memory usage = 33.8 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26     6000         25   26            -
#               26     6000         31   28         6  = where_0
#               26     6000         46   30   F    13  = where_0
#               26     6000         46   32         1 != where_16
#               26     7000         29    1         4 != _INT_3
#               26     6000         76    2   F    13  = where_13
#               26     6000         31    3        10 != where_3
#               26     6000         42    5         7  = where_9
#               26     7000         12    7   F     8 != where_2
#               26     7000         27    8   F    14  = where_0
#               26     7000         30    9        12  = where_13
#               26     7000         37   31        11 != where_10
#               26     7000         38   32         5  = where_5
#               26     7000         27    3         4  = where_15
#               26     7000         38    4         6 != _INT_5
#               26     7000         36    5   F    13  = where_6
#               26     7000         11    6        12 != where_16
#               26     8000         22    7   F     3  = truckConfigs_14
#               26     8000         27    8            -
#               26     8000         27   10   F     7  = where_1
#  ! Time = 4.98s, Average fail depth = 27, Memory usage = 33.8 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26     7000         26   11   F     1  = where_8
#               26     7000         29   12        12 != where_9
#               26     7000         20   14         5  = where_8
#               26     6000         40   16   F    12  = where_19
#               26     8000         32   17         0 != _INT_15
#               26     7000         26   18   F    13  = where_15
#               26     8000         48   19         1  = where_18
#               26     7000         45   20         7  = where_2
#               26     8000         16   21   F     0 != transitionCost_6
#               26     8000         14   22        13 != where_14
#               26     7000         31   23        11 != where_4
#               26     8000         30   25        11  = where_16
#               26     7000         38   26   F     6 != where_19
#               26     7000         25   27   F    10  = where_2
#               26     7000         46   28        12 != where_1
#               26     7000         15   29         5 != where_12
#               26     7000         38   30   F        -
#               26     8000         24   31         7  = where_13
#               26     8000         32   32   F    11 != where_13
#               26     8000          7    1        11 != where_10
#  ! Time = 5.50s, Average fail depth = 27, Memory usage = 33.8 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26     7000         28    2         4  = where_16
#               26     8000         24    3            -
#               26     8000         14    4   F    12  = where_8
#               26     8000         25    5         9 != where_15
#               26     8000         34    6        11 != where_19
#               26     9000         57    8         8 != where_7
#               26     8000         39    9        14 != where_13
#               26     8000         27   11         7  = where_1
#               26     8000         18   12   F     7  = where_9
#               26     8000         32   13         0  = where_20
#               26     8000         27   14   F     6  = where_6
#               26     8000         17   15         9 != where_16
#               26     7000         37   16   F    13  = where_13
#               26     9000          9   17         0 != customerOfTruck_13
#               26     8000         36   18   F    13  = where_8
#               26     9000         56   19   F     7  = where_19
#               26     9000         25   21         4 != truckConfigs_5
#               26     9000         45   22            -
#               26     7000         47   24         6  = where_8
#               26     8000         35   26        12 != where_14
#  ! Time = 5.50s, Average fail depth = 27, Memory usage = 33.8 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26     8000         17   27   F    11  = where_14
#               26     8000         14   28   F    13  = where_19
#               26     8000         34   29   F    11  = where_1
#               26     8000         49   30   F    10  = where_7
#               26     9000         24   31   F     0  = where_3
#               26     9000         12    5   F    13  = where_2
#               26     9000         39    6        10 != where_17
#               26     9000         32    7         7 != where_0
#               26    10000         46    8   F     1  = where_6
#               26     9000         22    9   F     2  = _INT_13
#               26     9000         35   10   F    12  = where_3
#               26     9000         18   11   F     8  = where_19
#               26     9000         18   12   F     4  = where_7
#               26     9000          7   13   F     2  = where_16
#               26     9000         35   14         7 != where_17
#               26     9000         20   15   F    11 != where_19
#               26     8000         49   16   F     8 != where_0
#               26     9000         20   18         1  = where_17
#               26    10000         28   19         3 != where_7
#               26     8000         26   20         3  = where_2
#  ! Time = 6.06s, Average fail depth = 27, Memory usage = 33.7 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26    10000          3   21         7 != where_20
#               26    10000         21   22   F    11  = where_6
#               26     8000         34   23   F     3  = where_4
#               26     8000         43   24   F     8  = where_19
#               26     9000         25   25   F    10  = transitionCost_10
#               26     9000         57   26   F     8  = where_13
#               26     9000         47   27   F    11  = where_11
#               26     9000         30   28   F    13 != where_11
#               26     9000         32   29   F     0 != transitionCost_6
#               26     9000         37   30            -
#               26    10000         23   31   F    14  = where_15
#               26     9000         26   32   F    12  = where_4
#               26     8000         23    2         7 != where_15
#               26     9000         31    3   F    13  = where_16
#               26     9000          2    4   F     8  = where_19
#               26    10000          1   17   F    13  = where_15
#               26     9000          3    1         8 != where_1
#               26     9000         20    2   F     4 != where_17
#               26    10000         17    4         9  = where_7
#               26    10000         12    5         7 != where_13
#  ! Time = 6.66s, Average fail depth = 27, Memory usage = 33.9 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26    10000         60    6   F     0  = where_3
#               26    11000         50    8         7 != where_20
#               26    10000          7    9        14  = where_20
#               26    10000         35   10         5 != where_15
#               26    10000         27   11   F    12  = where_19
#               26    10000         36   12         4  = where_8
#               26    10000         14   13         9  = where_9
#               26    10000         14   14   F     0  = where_11
#               26    10000         20   15         3 != where_10
#               26     9000         14   16   F    13 != where_5
#               26    10000         31   18        11 != where_8
#               26    11000         32   19        10 != where_11
#               26     9000         27   20         5 != where_16
#               26     9000         15   23        13 != where_8
#               26     9000         16   24   F     9  = where_10
#               26    10000         26   25   F     0 != transitionCost_10
#               26    10000         56   27         1  = where_1
#               26    10000         25   28        11 != where_15
#               26    10000         23   29         3 != _INT_17
#               26    10000         36   30         5 != where_1
#  ! Time = 6.66s, Average fail depth = 27, Memory usage = 33.9 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26    10000         38   32         4 != where_15
#               26    10000         41    1   F    13 != where_8
#               26    11000          1   17   F    14  = where_5
#               26    11000         44   22        12 != where_11
#               26    10000          8   23   F     9  = where_16
#               26    10000         29   24   F    13 != where_3
#               26    11000         13   25   F     0 != _INT_4
#               26    10000         63   26            -
#               26    11000         32   27        12 != where_16
#               26    11000         25   28         9 != where_16
#               26    11000         30   29         8 != where_3
#               26    11000         37   30   F     5  = where_17
#               26    11000         27   31         7 != where_11
#               26    11000         21   32   F    12  = where_2
#               26    11000         25    1         9  = where_8
#               26    10000         22    2   F    14  = where_3
#               26    10000         31    3   F    10 != where_16
#               26    11000         18    4   F     2  = truckConfigs_7
#               26    11000         63    5   F    13 != where_18
#               26    11000         17    6   F     7  = where_13
#  ! Time = 7.22s, Average fail depth = 27, Memory usage = 34.0 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26    10000         33    7   F     4  = where_19
#               26    12000         22    8        11 != where_9
#               26    11000          7    9   F     4 != truckConfigs_0
#               26    11000         36   10   F     4  = where_6
#               26    11000         26   11        14 != where_0
#               26    11000         48   12   F     7  = where_12
#               26    11000         28   13   F     0  = where_17
#               26    11000         33   14         2 != where_19
#               26    11000         33   15        14 != where_9
#               26    10000         21   16   F    10 != where_8
#               26    12000         10   17   F    13  = where_6
#               26    11000         28   18        12 != where_8
#               26    12000         34   19        14 != where_4
#               26    10000         27   20   F     4  = where_9
#               26    11000          1   21   F    11  = where_16
#               26    12000         59   22         3 != where_12
#               26    11000         37   23        12 != where_19
#               26    11000         55   24   F     7  = where_12
#               26    12000         32   25         3 != where_17
#               26    11000         38   26        11 != where_19
#  ! Time = 7.75s, Average fail depth = 27, Memory usage = 34.0 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26    12000         14   29         5 != where_8
#               26    12000         38   30   F     7 != where_17
#               26    12000         28   31         1 != where_4
#               26    12000         22   32        14 != where_5
#               26    12000         26    1   F    12  = where_15
#               26    11000         18    2         6 != where_4
#               26    11000         34    3         2 != where_0
#               26    12000         43    5         1  = where_11
#               26    12000         35    6         6 != where_0
#               26    11000         26    7   F     6 != where_2
#               26    12000         20    9   F    12  = where_11
#               26    12000         33   10   F    14  = where_1
#               26    12000         29   11   F    12  = where_11
#               26    12000         39   14         1  = where_15
#               26    12000         45   15        12 != where_1
#               26    11000         29   16         5 != where_12
#               26    13000          8   17   F    12  = where_4
#               26    12000         36   18        11 != where_10
#               26    13000         25   19   F     4  = where_7
#               26    11000         28   20   F     3  = where_11
#  ! Time = 7.77s, Average fail depth = 27, Memory usage = 34.0 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26    12000         15   21         4 != where_1
#               26    13000         42   22        11  = where_15
#               26    12000         35   23         2  = where_2
#               26    12000         33   24        11 != where_4
#               26    13000         12   25   F     3  = where_9
#               26    12000         34   26   F     6  = where_10
#               26    12000         12   27   F     3  = _INT_21
#               26    12000         69   28   F     6  = where_5
#               26    13000         13   29        13 != where_5
#               26    13000         27   30         0 != where_10
#               26    13000         22   32   F     6  = where_15
#               26    13000         10    1        13 != where_5
#               26    12000         31    2        11 != where_12
#               26    12000         18    3   F     9  = where_1
#               26    12000         11    4         3  = where_18
#               26    12000         25    7   F    13  = where_13
#               26    13000         50    8   F    13  = where_16
#               26    13000         35    9   F    13 != where_4
#               26    13000         36   10   F    12  = where_5
#               26    13000         45   11   F    11  = where_14
#  ! Time = 8.34s, Average fail depth = 27, Memory usage = 34.0 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26    12000         37   12            -
#               26    12000         13   13   F     3  = truckConfigs_1
#               26    13000         52   14        14 != where_0
#               26    13000         35   15         9  = where_10
#               26    12000         41   16   F        -
#               26    14000          1   17        13 != where_5
#               26    13000         25   18        13 != where_16
#               26    14000         19   19   F    13 != where_11
#               26    12000         31   20         5  = where_15
#               26    13000         10   21         7  = where_11
#               26    13000         34    2         6 != where_20
#               26    13000         24    3   F    13  = where_19
#               26    13000         10    4         4  = where_3
#               26    13000         18    5   F     2 != where_17
#               26    13000         27    6   F     9  = where_11
#               26    13000         19    7        14 != where_8
#               26    14000         22    8   F     4  = where_10
#               26    14000         22    9         0  = where_0
#               26    14000         54   10   F     3  = where_15
#               26    14000         18   11         9 != where_13
#  ! Time = 8.92s, Average fail depth = 27, Memory usage = 34.0 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26    13000         33   12   F    11 != where_16
#               26    13000         13   13         9  = where_20
#               26    14000         15   14        10  = where_7
#               26    14000         43   15         8 != where_17
#               26    13000         18   16            -
#               26    15000         17   17         5 != where_6
#               26    14000         40   18   F     5  = where_6
#               26    15000         17   19         1 != where_9
#               26    13000         33   20   F     9  = where_16
#               26    14000         10   21   F    12  = where_5
#               26    14000         25   22            -
#               26    13000         11   23         2 != where_3
#               26    13000         25   24   F     9  = where_7
#               26    14000         14   25        13 != where_15
#               26    13000         34   26   F    10  = where_16
#               26    13000         25   27   F     3 != _INT_18
#               26    13000         36   28   F    13  = where_11
#               26    14000         11   29   F    13  = where_3
#               26    14000         34   30        13 != where_4
#               26    13000         26   31   F     1  = where_1
#  ! Time = 8.92s, Average fail depth = 27, Memory usage = 34.0 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26    14000         25   32   F        -
#               26    14000          1    1         1  = where_3
#               26    14000         30    2   F    11 != where_14
#               26    14000         30    3   F    13  = where_1
#               26    14000         17    4   F     0 != truckConfigs_3
#               26    14000         37    5        14 != where_7
#               26    14000         40    6         8 != where_16
#               26    14000         16    7   F     9  = where_8
#               26    15000         22    8   F    14  = where_0
#               26    15000         19    9        11 != where_18
#               26    15000         23   10   F    11 != where_16
#               26    15000          4   11   F    13 != where_14
#               26    14000         37   12         9  = where_13
#               26    14000         23   13        12 != where_4
#               26    15000         32   14            -
#               26    15000         24   15   F     3 != _INT_4
#               26    14000         21   16         5  = where_12
#               26    16000         11   17   F    14  = where_16
#               26    15000         33   18   F        -
#               26    14000         52   20   F     7  = where_10
#  ! Time = 9.45s, Average fail depth = 27, Memory usage = 34.0 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26    15000         14   21   F    10  = where_15
#               26    15000         56   22         8 != where_16
#               26    14000         32   23   F    11  = where_11
#               26    14000         28   24        10 != where_2
#               26    15000         17   25   F    13  = where_11
#               26    14000         34   26         4 != where_11
#               26    14000         44   27         8 != where_19
#               26    14000         42   28   F    13  = where_11
#               26    15000         16   29         2 != where_19
#               26    15000         24   30         1 != where_11
#               26    14000         16   31        10 != where_20
#               26    15000         32   32         3  = where_19
#               26    15000         22    1   F     4  = where_16
#               26    16000         40   32            -
#               26    16000         20    1   F     0 != where_1
#               26    15000         24    2   F     0  = truckConfigs_6
#               26    15000         45    3   F     2 != where_5
#               26    15000         24    4         5 != where_1
#               26    15000         39    5   F    10  = where_2
#               26    15000         31    6   F     4  = where_0
#  ! Time = 10.08s, Average fail depth = 27, Memory usage = 34.1 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26    16000         33    8        10 != where_1
#               26    16000         30   10         4  = where_15
#               26    15000         31   12   F     9  = where_13
#               26    15000         22   13   F    14  = where_6
#               26    16000         39   14         8  = where_8
#               26    16000         24   15   F     2  = where_1
#               26    15000         35   16   F    13  = where_8
#               26    17000         11   17         0 != where_11
#               26    16000         23   19   F     8  = where_1
#               26    15000         27   20            -
#               26    16000         18   21        12 != where_16
#               26    15000         29   23   F    12  = where_12
#               26    15000         17   24   F     7  = where_7
#               26    16000          9   25         5 != where_7
#               26    15000         22   26   F        -
#               26    15000         21   27        10 != where_18
#               26    15000         39   28   F     6  = where_11
#               26    16000         11   29         2 != where_14
#               26    15000          3   31        13 != where_2
#               26    16000         41    5         7 != where_6
#  ! Time = 10.61s, Average fail depth = 27, Memory usage = 34.1 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26    16000         41    6   F    14  = where_16
#               26    15000         26    7        10 != where_19
#               26    17000         44    8   F    12  = where_19
#               26    16000         29    9         5  = where_6
#               26    17000         36   10        14 != where_11
#               26    16000         41   11   F     9  = where_15
#               26    16000         25   12   F     2 != where_17
#               26    16000         18   13        11  = where_3
#               26    17000         43   15   F     4  = where_20
#               26    18000         11   17   F    14  = where_12
#               26    16000         46   18   F     5  = where_11
#               26    17000         25   19         1 != where_1
#               26    16000         37   20   F     3  = where_1
#               26    16000         32   22   F    13  = where_14
#               26    16000         45   23   F    11  = where_10
#               26    16000         30   24        11 != where_15
#               26    17000         14   25        13 != where_0
#               26    16000         55   26   F    13  = where_17
#               26    16000         20   27   F    13 != where_14
#               26    17000         13   29   F    13  = where_16
#  ! Time = 10.66s, Average fail depth = 27, Memory usage = 34.1 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26    16000         54   30   F    11  = where_16
#               26    16000         52   31        13 != where_15
#               26    17000         44   32            -
#               26    17000         22    1        10 != where_12
#               26    16000          9    2   F    12  = where_7
#               26    16000         38    3   F     4 != where_2
#               26    16000          1    4         6  = where_5
#               26    17000         22    5   F    11  = where_7
#               26    17000         39    6   F     7  = where_13
#               26    18000         26    8        11 != where_7
#               26    17000         26    9        11 != where_15
#               26    17000         49   11         8  = where_16
#               26    17000         36   12   F    14 != where_2
#               26    17000          5   13        12 != where_20
#               26    17000         44   14         4 != where_17
#               26    18000         33   15         6  = where_20
#               26    16000         23   16         6  = where_12
#               26    19000         11   17        11 != where_6
#               26    17000         38   18        13 != where_0
#               26    18000         28   19   F     1  = where_11
#  ! Time = 11.13s, Average fail depth = 27, Memory usage = 34.1 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26    17000         31   20         7 != where_17
#               26    17000         16   21         3  = where_5
#               26    17000         27   22   F     7  = where_17
#               26    17000         39   23         5 != _INT_17
#               26    18000         11   25   F    14  = where_0
#               26    17000         18   26         5  = where_10
#               26    17000         37   27   F     6  = where_10
#               26    16000         47   28         9 != where_3
#               26    18000         11   29   F    10  = where_20
#               26    17000         34   30        14 != where_16
#               26    17000         50   31   F     9  = where_16
#               26    18000         28    1        11 != where_11
#               26    17000         49    3   F    13  = where_19
#               26    17000         10    4   F    10  = where_10
#               26    18000         26    5   F    12 != where_18
#               26    18000         41    6         8  = where_9
#               26    16000         66    7   F     3  = where_16
#               26    19000         22    8   F    13  = where_19
#               26    18000         20    9         2 != where_16
#               26    18000         37   10        13 != where_4
#  ! Time = 11.72s, Average fail depth = 27, Memory usage = 34.1 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26    18000         46   11   F     1 != _INT_7
#               26    18000         44   12   F     1  = where_4
#               26    18000         22   14   F    11  = where_2
#               26    17000         23   16         7 != where_3
#               26    20000         11   17        14 != where_15
#               26    18000         41   18         7 != where_14
#               26    19000         28   19        14 != where_20
#               26    18000         37   20         1 != where_10
#               26    18000         15   21   F     2  = where_8
#               26    18000         32   22   F     4  = where_19
#               26    17000         43   24   F    12  = where_10
#               26    19000         11   25         2  = where_10
#               26    18000         31   26   F    13  = where_15
#               26    18000         37   27        12  = where_8
#               26    17000         53   28        14 != where_7
#               26    19000         18   29        11  = where_5
#               26    18000         44   30        13 != where_9
#               26    18000         51   31   F     6  = where_8
#               26    18000         12   32   F     5  = where_15
#               26    19000         13    1   F     6  = where_6
#  ! Time = 11.72s, Average fail depth = 27, Memory usage = 34.1 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26    17000         44    2   F    13 != where_19
#               26    18000         12    4        12 != where_7
#               26    18000          1   13         0 != where_3
#               26    18000         34   24   F    11  = where_7
#               26    20000         15   25         4  = where_19
#               26    19000         14   26   F    13  = where_15
#               26    19000         30   27         2 != where_18
#               26    18000         25   28   F     9  = where_19
#               26    20000         13   29        13 != where_4
#               26    19000         52   31   F     9  = where_2
#               26    19000         25   32   F        -
#               26    20000         16    1   F     5 != where_10
#               26    18000         39    2        11  = where_9
#               26    18000         30    3   F    13 != where_19
#               26    19000         11    4   F    14  = where_13
#               26    19000         34    5   F    12  = where_10
#               26    19000         39    6        11 != where_15
#               26    20000         12    8        10 != where_17
#               26    19000          1    9   F     8  = where_11
#               26    19000         47   10            -
#  ! Time = 12.29s, Average fail depth = 26, Memory usage = 34.4 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26    19000         46   11   F    12  = where_13
#               26    19000         37   12   F    13 != where_6
#               26    19000         14   13   F    13  = where_12
#               26    19000         44   14   F     7  = where_6
#               26    19000         34   15         7 != where_18
#               26    18000         43   16   F     7  = where_2
#               26    21000         11   17   F    14  = where_0
#               26    20000         28   19   F    12  = where_8
#               26    19000         39   20   F        -
#               26    19000         13   21   F     8  = where_11
#               26    19000         33   22            -
#               26    18000          1   23   F    12  = where_11
#               26    19000         21   24   F    13  = where_16
#               26    21000         18   25         9 != where_19
#               26    20000         36   26   F     2  = where_5
#               26    20000         36   27   F    13  = where_3
#               26    19000         45   28   F     6  = where_11
#               26    21000         11   29        12 != where_16
#               26    19000         45   30         5 != where_16
#               26    20000         48   31   F    12  = where_15
#  ! Time = 12.88s, Average fail depth = 26, Memory usage = 34.4 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26    20000         68   32            -
#               26    21000          1    1   F    13  = where_20
#               26    19000         30    2        11  = where_9
#               26    19000         28    3   F    13 != where_10
#               26    20000         15    4        13 != where_2
#               26    20000         26    5   F        -
#               26    20000         69    6   F    14  = where_18
# ...
#               26    25000         28   28        12 != where_15
#  ! Time = 16.68s, Average fail depth = 26, Memory usage = 34.8 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26    27000         31   29   F    12  = where_6
#               26    25000         53   30         1  = where_13
#               26    27000         56   31   F    13  = where_6
#               26    27000         27   32        14 != where_19
#               26    28000         23    1   F    14  = where_8
#               26    26000         46    2   F    13  = where_8
#               26    26000         17    3         7 != where_16
#               26    26000         79    4        10 != where_19
#               26    27000         11    5   F     4  = where_12
#               26    26000         15    8         0 != where_1
#               26    26000         11    9   F    12  = where_15
#               26    25000         16   10   F     8  = where_4
#               26    26000         37   11         5 != truckConfigs_3
#               26    26000         38   12         1 != where_15
#               26    26000         19   13   F     9  = where_6
#               26    26000         34   14   F    11  = where_11
#               26    26000         41   16   F        -
#               26    28000         20   17         7 != where_4
#               26    26000         33   18        13 != where_9
#               26    28000         21   19   F    10  = where_17
#  ! Time = 16.70s, Average fail depth = 26, Memory usage = 34.8 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26    27000         28   20   F    13 != where_4
#               26    26000         22   21         0 != where_15
#               26    26000         29   22   F    13 != where_2
#               26    26000         37   23   F    13  = where_13
#               26    25000         22   24            -
#               26    27000         44   25         2 != where_10
#               26    24000          5    7   F     4  = where_4
#               26    28000         45   26   F     5  = where_7
#               26    27000         21   27   F     3  = _INT_7
#               26    26000         20   28         8 != where_11
#               26    28000         31   29   F    14  = where_1
#               26    26000         18   30         8 != where_16
#               26    28000         39   32   F     7  = where_8
#               26    27000         44    2        12 != where_3
#               26    27000         23    3         4 != where_17
#               26    28000         45    5         9 != where_19
#               26    27000         42    6            -
#               26    25000         20    7   F    11  = where_13
#               26    27000         30    8         7 != where_1
#               26    27000         16    9   F    14  = where_12
#  ! Time = 17.22s, Average fail depth = 25, Memory usage = 34.9 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26    26000         42   10   F        -
#               26    27000         28   11   F     2 != truckConfigs_1
#               26    27000         31   12   F     5  = where_8
#               26    27000         16   13   F    10  = where_0
#               26    27000         44   14   F     3 != where_7
#               26    27000         18   15   F     0  = transitionCost_3
#               26    27000         41   16         3  = where_6
#               26    27000         30   18        10 != where_5
#               26    29000         22   19   F     6 != where_5
#               26    28000         17   20   F    13 != where_8
#               26    27000         25   21         5  = where_19
#               26    27000         38   23   F     8  = where_13
#               26    26000         24   24         1 != where_15
#               26    28000         15   25   F     0  = where_1
#               26    29000         19   26         9 != where_19
#               26    28000         19   27        12 != where_3
#               26    27000         59   28         7  = where_9
#               26    29000         32   29   F     1  = where_13
#               26    27000         18   30   F    12  = where_16
#               26    28000         20   31         5  = where_1
#  ! Time = 17.79s, Average fail depth = 25, Memory usage = 34.9 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26    29000         18    1   F    12  = where_5
#               26    28000         58    2   F    13  = where_17
#               26    28000         44    3        11 != where_16
#               26    29000         24    5        14 != where_6
#               26    28000         36    6            -
#               26    26000         16    7   F     8 != where_11
#               26    28000         30    8         8 != where_11
#               26    28000         15    9   F    14  = where_19
#               26    27000         21   10   F    14  = where_7
#               26    28000         37   11         3 != truckConfigs_12
#               26    28000         17   13   F    12  = where_11
#               26    28000         34   14         8 != where_11
#               26    28000         33   15        10  = where_14
#               26    28000         37   16   F        -
#               26    28000         29   18   F    11  = where_4
#               26    30000         23   19         3 != where_16
#               26    28000         12   21   F    12  = where_0
#               26    27000         78   22        12 != where_1
#               26    28000         37   23         0 != where_12
#               26    27000         35   24   F    11  = where_10
#  ! Time = 17.79s, Average fail depth = 25, Memory usage = 34.9 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26    29000         19   25   F     3 != where_1
#               26    27000         37    4   F    13  = where_15
#               26    29000         36   17   F    13  = where_1
#               26    30000         44   26   F     3  = where_11
#               26    29000         28   27   F    10  = where_20
#               26    28000         11   28            -
#               26    30000         25   29   F     1  = where_16
#               26    28000         31   30   F     4  = where_4
#               26    29000         27   31         9 != where_4
#               26    29000         39   32   F    14  = where_11
#               26    30000         77    1        12 != where_16
#               26    29000         69    2         8 != where_17
#               26    29000         28    3         5 != where_10
#               26    28000         15    4        12 != where_12
#               26    30000         26    5   F    12  = where_1
#               26    29000         31    6   F     2  = where_4
#               26    27000         25    7   F     7  = where_4
#               26    29000         25    8         9  = where_19
#               26    29000         14    9         1  = where_17
#               26    28000         24   10   F    11  = where_15
#  ! Time = 18.36s, Average fail depth = 25, Memory usage = 35.1 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26    29000         22   11         4 != where_13
#               26    28000         31   12        11 != where_19
#               26    29000         37   14         5 != where_2
#               26    29000         33   15   F     0 != _INT_9
#               26    29000         36   16         8 != where_15
#               26    30000         51   17   F     9 != where_12
#               26    29000         52   18   F    11  = where_1
#               26    29000         24   20   F        -
#               26    29000         11   21         1 != where_14
#               26    28000         22   22         0  = where_2
#               26    29000         39   23   F     1  = where_0
#               26    28000         10   24   F     7  = where_2
#               26    30000          8   25         5 != truckConfigs_0
#               26    29000         41   22   F     6 != where_6
#               26    30000         18   23   F    14  = where_16
#               26    29000         37   24   F     8  = where_11
#               26    31000          4   25         6 != _INT_18
#               26    30000         28   27         9  = where_1
#               26    29000         33   28   F     3  = where_0
#               26    31000         32   29   F     2  = where_19
#  ! Time = 18.86s, Average fail depth = 25, Memory usage = 35.1 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26    29000         60   30         7 != where_6
#               26    30000         21   31         9 != where_8
#               26    30000         19   32   F     9  = where_17
#               26    30000         61    2   F    11  = where_4
#               26    30000         33    3   F     3  = where_11
#               26    29000         15    4         6 != where_8
#               26    31000         34    5        12 != where_8
#               26    30000         19    6         7  = where_10
#               26    28000         49    7         2 != where_14
#               26    30000         21    8         4 != where_17
#               26    29000         10   10   F    13 != where_15
#               26    30000         33   11   F     2  = truckConfigs_1
#               26    29000         36   12            -
#               26    29000         18   13   F    10  = where_11
#               26    30000         39   14         5  = where_15
#               26    30000         31   15         4  = _INT_11
#               26    30000         18   16   F     5  = where_10
#               26    31000         53   17   F    13  = where_12
#               26    31000         27   19   F     3  = where_13
#               26    30000         18   20        10 != where_7
#  ! Time = 18.88s, Average fail depth = 25, Memory usage = 35.1 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26    30000         18   21        11 != where_5
#               26    30000         38   18   F     9  = where_19
#               26    32000         15   19        11 != where_1
#               26    31000         38   20   F     5  = where_16
#               26    31000         15   21        10 != where_4
#               26    30000         38   22         4 != where_18
#               26    31000         18   23         5 != where_15
#               26    30000         37   24         6  = where_18
#               26    32000          1   25         3 != where_15
#               26    31000         16   26        14 != where_1
#               26    31000         34   27   F    14  = where_0
#               26    30000         38   28   F    13  = where_6
#               26    31000         18   31   F     0  = where_16
#               26    31000         31   32        11 != where_11
#               26    31000         40    1         3  = where_2
#               26    31000         20    3         9 != where_11
#               26    30000         21    4        14 != where_19
#               26    32000         57    5         4 != where_6
#               26    31000         27    6   F     2  = where_1
#               26    29000         46    7         5 != where_2
#  ! Time = 19.45s, Average fail depth = 25, Memory usage = 35.2 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26    30000         81    9         4  = where_16
#               26    30000         16   10         6 != where_12
#               26    30000         36   12         7 != where_6
#               26    30000         13   13        10 != where_8
#               26    31000         47   14   F    13  = where_13
#               26    31000         36   16   F    10  = where_4
#               26    32000         53   17   F    12  = where_13
#               26    32000         13   29         4 != where_6
#               26    30000         24   30        12 != where_0
#               26    32000         36   31   F     2 != where_1
#               26    32000         52   32         0 != where_11
#               26    32000         13    1         3 != where_7
#               26    31000         49    2         9 != where_5
#               26    32000         11    3         8  = where_5
#               26    31000         46    4         4  = where_13
#               26    33000         18    5   F     4  = where_6
#               26    32000         50    6   F    13  = where_13
#               26    30000         46    7   F    14  = where_17
#               26    31000         21    8        11 != where_16
#               26    31000         28   10   F     2  = where_5
#  ! Time = 19.90s, Average fail depth = 25, Memory usage = 35.3 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#               26    31000         44   11         2 != where_1
#               26    31000         40   12         7  = where_19
#               26    31000         17   13   F     3 != where_16
#               26    32000         22   14         9 != where_12
#               26    31000         24   15         0 != where_8
#               26    32000         26   16        14 != where_16
#               26    33000         67   17         2 != where_10
#               26    31000         48   18   F    13  = where_13
#               26    33000         28   19        13 != where_8
#               26    32000         20   20        12 != where_19
#               26    32000         12   21        12 != where_0
#               26    31000         17   22         6  = where_0
#               26    32000         25   23   F     9  = where_10
#               26    31000         33   24         2  = where_6
#               26    33000          1   25   F     0 != _INT_9
#               26    32000         37   26   F     6  = where_1
#               26    31000         34   28   F     9  = where_11
#               26    33000         18   29         6  = where_16
#               26    32000         10   27   F     2 != where_19
#               26    31000         25   30        12 != where_1
#  ! Time = 20.16s, Average fail depth = 25, Memory usage = 35.4 MB
#  ! Current objective is 26; 13
#  ! Current bound is 4; -9007199254740989 (gap is 84.62% @ crit. 1 of 2)
#  !          Best Branches  Non-fixed    W       Branch decision
#  ! ----------------------------------------------------------------------------
#  ! Search terminated by limit, 5 solutions found.
#  ! Best objective         : 26; 13 (gap is 84.62% @ crit. 1 of 2)
#  ! Best bound             : 4; -9007199254740989
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 1037466
#  ! Number of fails        : 501047
#  ! Total memory usage     : 36.9 MB (36.8 MB CP Optimizer + 0.1 MB Concert)
#  ! Time spent in solve    : 20.24s (20.24s engine + 0.00s extraction)
#  ! Search speed (br. / s) : 51283.5
#  ! ----------------------------------------------------------------------------

# %% [markdown]
# ### Step 3: Investigate the solution and then run an example analysis

# %%
from sys import stdout
if msol.is_solution():
    print("Solution: ")
    ovals = msol.get_objective_values()
    print("   Configuration cost: {}, number of deliveries: {}".format(ovals[0], ovals[1]))
    for i in range(maxDeliveries):
        ld = msol.get_value(load[i])
        if ld > 0:
            stdout.write("   Delivery {:2d}: config={}".format(i,msol.get_value(truckConfigs[i])))
            stdout.write(", items=")
            for j in range(nbOrders):
                if (msol.get_value(where[j]) == i):
                    stdout.write(" <{}, {}, {}>".format(j, productType[j], volumes[j]))
            stdout.write('\n')
else:
    stdout.write("Solve status: {}\n".format(msol.get_solve_status()))
# Out:
# Solution:
#    Configuration cost: 26, number of deliveries: 13
#    Delivery  0: config=2, items= <17, 2, 11>
#    Delivery  1: config=2, items= <10, 2, 4> <11, 2, 7>
#    Delivery  2: config=2, items= <1, 2, 4>
#    Delivery  3: config=2, items= <12, 2, 3> <14, 2, 2>
#    Delivery  4: config=1, items= <15, 1, 5>
#    Delivery  5: config=1, items= <0, 1, 3> <3, 1, 2> <4, 1, 5>
#    Delivery  6: config=1, items= <5, 1, 4>
#    Delivery  7: config=0, items= <2, 0, 3>
#    Delivery  8: config=0, items= <18, 0, 1> <19, 0, 6> <20, 0, 3>
#    Delivery  9: config=0, items= <8, 0, 5> <13, 0, 5>
#    Delivery 10: config=0, items= <6, 0, 11>
#    Delivery 11: config=0, items= <16, 0, 6>
#    Delivery 12: config=0, items= <7, 0, 4> <9, 0, 2>

# %% [markdown]
# ## Summary
#
# You have learned how to set up and use the IBM Decision Optimization CPLEX Modeling for Python to formulate and solve a Constraint Programming model.

# %% [markdown]
# #### References
# * <a href="https://rawgit.com/IBMDecisionOptimization/docplex-doc/master/docs/index.html" target="_blank" rel="noopener noreferrer">Decision Optimization CPLEX Modeling for Python documentation</a>
# * <a href="https://dataplatform.cloud.ibm.com/docs/content/wsj/getting-started/welcome-main.html?context=cpdaas" target="_blank" rel="noopener noreferrer">IBM Cloud Pak for Data as a Service documentation</a>
# * <a href="https://dataplatform.cloud.ibm.com/docs/content/wsj/getting-started/welcome-main.html?context=wx" target="_blank" rel="noopener noreferrer">IBM watsonx.ai documentation</a>

# %% [markdown]
# <hr>
# Copyright © 2017-2024. This notebook and its source code are released under the terms of the MIT License.
